# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# We define the needed libraries here

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from time import process_time
from scipy.special import xlogy
from keras.datasets import cifar10
from sklearn.decomposition import PCA
from tensorflow.keras.utils import to_categorical
from numpy import linalg as LA
from sklearn.model_selection import train_test_split

# %% [markdown]
# Load all the data here

# %%
def calc_cov(data_set, mean):
    res = np.zeros([data_set.shape[1],data_set.shape[1]])
    for i in range(data_set.shape[0]):
        vect = np.subtract(data_set[i], mean)
        vect = np.array([vect])
        res += np.matmul(vect.T, vect)

    return res/(data_set.shape[0]-1)

def relu(x):
  return np.maximum(x, np.zeros_like(x))

def Cal_accuracy(True_label, Estimated_label):
  return np.count_nonzero(np.transpose(True_label)==np.array(Estimated_label))/True_label.size

def step(x):
  return 1*(x > np.zeros_like(x))

def encode(vect, idx, landa):
  temp = np.multiply(step(landa - vect),-1)
  temp[idx] = 1
  return temp

def gelu(x):
    return 0.5 * np.multiply(x, 1 + np.tanh(np.sqrt(2 / np.pi) * (x + 0.044715 * np.power(x, 3))))

def Dgelu(x):
  return np.divide(0.053516 * np.power(x, 3) + np.multiply(0.398942, x) , np.power(np.cosh(0.0356774 * np.power(x, 3) +np.multiply(0.79788, x)),2)) + 0.5 * ( 1 + np.tanh(np.sqrt(2 / np.pi) * (x + 0.044715 * np.power(x, 3))))

def RBF_encode(data, number_class, dim):
  data = np.reshape(data, (dim,int(data.size/dim)), order='F')
  data = LA.norm(data,1, axis = 0)
  data = np.reshape(data, (number_class, int(data.size/number_class)), order='F')
  return data

def expand(x):
  temp = []
  for i in range(len(x)):
    temp.append(x[i])
    temp.append(x[i])
  return temp

# %%
def preprocess(apply_PCA):

    (train_data, train_labels), (test_data, test_labels) = cifar10.load_data()


    train_data = train_data.reshape(-1, 32*32*3).astype('float32') / 255
    test_data = test_data.reshape(-1, 32*32*3).astype('float32') / 255


    train_data, val_data, train_labels, val_labels = train_test_split(train_data, train_labels, test_size=0.1, random_state=1)
    
    if apply_PCA:
      Data_avg = np.mean(train_data, axis = 0)
      Data_cov = calc_cov(train_data, Data_avg)
      EigenValues, EigenVectors = LA.eigh(Data_cov) 
      New_EigenValues = EigenValues[-128:]
      New_EigenVectors = EigenVectors[:,-128:]
      train_data = np.matmul(train_data, New_EigenVectors)
      test_data = np.matmul(test_data, New_EigenVectors)
      val_data = np.matmul(val_data, New_EigenVectors)

    return train_data, train_labels, val_data, val_labels, test_data, test_labels

# %%
data = preprocess(False)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 3s 0us/step

# %%
Train_data, Train_label, Val_data, Val_label, Test_data, Test_label = data

# %%
s = np.random.uniform(size=(2, 2))
print(s)
# Out:
# [[0.91704866 0.4635829 ]
#  [0.36354352 0.58199162]]

# %% [markdown]
# Here we define the class network

# %%
class Network:
  def __init__(self, input_node, hidden_layer, hidden_node, output_node):
    self.number_input_node = input_node
    self.number_hidden_layer = hidden_layer
    self.number_hidden_node = hidden_node
    self.number_class_output = output_node
    self.distance_dim = 2
    self.weight = {}
    self.layer = {}
    self.batch_data = {}
    self.batch_label = {}
    self.diff_weight = {}
    self.score = []
    self.result = []
    self.init_weight()
    self.loss = []
    self.back_prob_output = []
    for i in range(self.number_hidden_layer + 1):
      self.diff_weight["w" + str(i) + "_prev"] = 0
      self.diff_weight["b" + str(i) + "_prev"] = 0
    self.momentum = 0.9
    self.learning_rate = 0.001
    self.number_turn = 100
    self.batchS = 128
    self.accuracy_graph = []
    self.loss_graph = []
    self.landa = 550
    self.accuracy_graph_epoch = []

  def set_turn(self, x):
    self.number_turn = x

  def set_learning_rate(self, x):
    self.learning_rate = x

  def set_batch_size(self, x):
    self.batchS = x
  
  def load_weights(self):
    for i in range(self.number_hidden_layer + 1):
      self.weight["w" + str(i)] = (pd.read_csv("/content/drive/My Drive/Deep Learning Course Spring 99/DataSets/Fashion-MNIST/w" + str(i) + ".csv", header=None)).to_numpy()
      self.weight["b" + str(i)] = (pd.read_csv("/content/drive/My Drive/Deep Learning Course Spring 99/DataSets/Fashion-MNIST/b" + str(i) + ".csv", header=None)).to_numpy()

  def init_weight(self):
    # self.weight["w0"] = np.random.normal(loc=0, scale=0.14, size=(self.number_hidden_node[0], self.number_input_node))
    # self.weight["b0"] = np.random.normal(loc=0, scale=0.14, size=(self.number_hidden_node[0], 1))

    self.weight["w0"] = np.random.uniform(size=(self.number_hidden_node[0], self.number_input_node))
    self.weight["b0"] = np.random.uniform(size=(self.number_hidden_node[0], 1))

    for i in range(self.number_hidden_layer - 1):
      self.weight["w" + str(i+1)] = (np.random.uniform(size=(self.number_hidden_node[i+1], self.number_hidden_node[i])))
      self.weight["b" + str(i+1)] = (np.random.uniform(size=(self.number_hidden_node[i+1], 1)))

      # self.weight["w" + str(i+1)] = (np.random.normal(loc=0, scale=0.14, size=(self.number_hidden_node[i+1], self.number_hidden_node[i])))
      # self.weight["b" + str(i+1)] = (np.random.normal(loc=0, scale=0.14, size=(self.number_hidden_node[i+1], 1)))

    self.weight["w" + str(self.number_hidden_layer)] = np.random.uniform(size=(self.number_class_output * self.distance_dim, self.number_hidden_node[self.number_hidden_layer-1]))
    self.weight["b" + str(self.number_hidden_layer)] = np.random.uniform(size=(self.number_class_output * self.distance_dim, 1))

    # self.weight["w" + str(self.number_hidden_layer)] = np.random.normal(loc=0, scale=0.14, size=(self.number_class_output * self.distance_dim, self.number_hidden_node[self.number_hidden_layer-1]))
    # self.weight["b" + str(self.number_hidden_layer)] = np.random.normal(loc=0, scale=0.14, size=(self.number_class_output * self.distance_dim, 1))
    
  def forward(self, data):
    self.layer.clear()
    self.layer["input"] = data
    if len(data) == data.size:
      self.layer["z0"] = (np.matmul(self.weight["w0"],np.transpose(data))).reshape((len(MyNetwork.weight["w0"]),1))
    else:
      self.layer["z0"] = (np.matmul(self.weight["w0"], np.transpose(data)))
    self.layer["z0"] = np.add(self.layer["z0"], self.weight["b0"])
    self.layer["r0"] = gelu(self.layer["z0"])
    self.layer["s0"] = Dgelu(self.layer["z0"])
    for i in range(self.number_hidden_layer - 1):
      self.layer["z" + str(i + 1)] = np.matmul(self.weight["w" + str(i + 1)], self.layer["r" + str(i)])
      self.layer["z" + str(i + 1)] = np.add(self.layer["z" + str(i + 1)], self.weight["b" + str(i + 1)])
      self.layer["r" + str(i + 1)] = gelu(self.layer["z" + str(i + 1)])
      self.layer["s" + str(i + 1)] = Dgelu(self.layer["z" + str(i + 1)])
    self.layer["z" + str(self.number_hidden_layer)] = np.matmul(self.weight["w" + str(self.number_hidden_layer)], self.layer["r" + str(self.number_hidden_layer - 1)])
    self.layer["z" + str(self.number_hidden_layer)] = np.add(self.layer["z" + str(self.number_hidden_layer)], self.weight["b" + str(self.number_hidden_layer)])
    self.layer["r" + str(self.number_hidden_layer)] = RBF_encode(self.layer["z" + str(self.number_hidden_layer)], self.number_class_output, self.distance_dim)
    self.layer["s" + str(self.number_hidden_layer)] = np.sign(self.layer["z" + str(self.number_hidden_layer)])
    self.score = self.layer["r" + str(self.number_hidden_layer)]
    temp = self.decide_RBF(self.score)
    return temp
  
  def decide_RBF(self, data):
    self.result = np.argmin(data, axis=0)
    return self.result

  def cal_loss(self, label) :
    self.loss.clear()
    self.back_prob_output = []
    temp = np.transpose(self.score)
    for i in range(len(label)):
      self.loss.append(np.sum(relu((self.landa - temp[i]))) - relu(self.landa- temp[i][label[i]]) + temp[i][label[i]])
      self.back_prob_output.append(encode(temp[i], label[i], self.landa))
    self.back_prob_output = np.transpose(self.back_prob_output)/len(label)
    total_loss = np.sum(self.loss)/len(self.loss)
    self.loss_graph.append(total_loss)
    return total_loss

  def batching(self, data, label):
    batch_size = self.batchS
    if len(data) == data.size:
      batch[0] = data
      return
    for i in range(int(len(data)/batch_size)):
      self.batch_data[i] = data[i*batch_size:(i+1)*batch_size]
      self.batch_label[i] = label[i*batch_size:(i+1)*batch_size]
    if len(data)%batch_size != 0:
      self.batch_data[int(len(data)/batch_size)] = data[int(len(data)/batch_size)*batch_size:len(data)]
      self.batch_label[int(len(data)/batch_size)] = label[int(len(data)/batch_size)*batch_size:len(data)]

  def back_prob(self):
    temp = np.multiply(expand(self.back_prob_output), self.layer["s" + str(self.number_hidden_layer)])
    for i in range(self.number_hidden_layer):
      self.diff_weight["w" + str(self.number_hidden_layer - i)] = np.matmul(temp, np.transpose(self.layer["r"+ str(self.number_hidden_layer-1-i)]))
      self.diff_weight["b" + str(self.number_hidden_layer - i)] = np.matmul(temp, np.ones((len(temp[0]), 1)))
      temp = np.matmul(np.transpose(self.weight["w" + str(self.number_hidden_layer - i)]), temp)
      temp = np.multiply(self.layer["s" + str(self.number_hidden_layer - i - 1)], temp)
    self.diff_weight["w0"] = np.matmul(temp, self.layer["input"])
    self.diff_weight["b0"] = np.matmul(temp, np.ones((len(temp[0]), 1)))

    for i in range(self.number_hidden_layer + 1):
      self.diff_weight["w" + str(i) + "_prev"] = ((1 - self.momentum) * self.diff_weight["w" + str(i)] + self.momentum * self.diff_weight["w" + str(i) + "_prev"])
      self.diff_weight["b" + str(i) + "_prev"] = ((1 - self.momentum) * self.diff_weight["b" + str(i)] + self.momentum * self.diff_weight["b" + str(i) + "_prev"])

    for i in range(self.number_hidden_layer + 1):
      self.weight["w" + str(i)] = self.weight["w" + str(i)] - self.diff_weight["w" + str(i) + "_prev"] * self.learning_rate
      self.weight["b" + str(i)] = self.weight["b" + str(i)] - self.diff_weight["b" + str(i) + "_prev"] * self.learning_rate

  def Train_Network(self, data, label):
    epoch = 0
    self.accuracy_graph_epoch.append((self.Test_Network(data, label)))
    for j in range(self.number_turn):
      self.batching(data, label)
      for i in range(len(self.batch_data)):
        self.forward(self.batch_data[i])
        self.accuracy_graph.append(Cal_accuracy(self.batch_label[i], self.forward(self.batch_data[i])))
        print(self.cal_loss(self.batch_label[i]), " step ", i," of the epoch ", j , "the steps is: ", epoch)
        self.back_prob()
        epoch += 1
      self.accuracy_graph_epoch.append((self.Test_Network(data, label)))

  def Test_Network(self, data, label):
    if(len(data) == data.size):
      temp = self.batchS
      self.batchS = 1
      print(Cal_accuracy(label, MyNetwork.forward(data)))
      self.batchS = temp
    else:
      print(Cal_accuracy(label, MyNetwork.forward(data)))
    return (Cal_accuracy(label, MyNetwork.forward(data)))

# %% [markdown]
# We are going to define a Network call MyNetwork and in order to save it's weights we are not going to touch it

# %%
INPUT_DIM = 32*32*3
MyNetwork = Network(INPUT_DIM,1,[150],10)
MyNetwork.set_learning_rate(0.001)
MyNetwork.set_turn(50)
MyNetwork.set_batch_size(128)
start = process_time()
MyNetwork.Train_Network(Train_data, Train_label)
print('time of train :', process_time()-start)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:28: RuntimeWarning: overflow encountered in cosh
# Streaming output truncated to the last 5000 lines.
# 8004.870413354783  step  132  of the epoch  0 the steps is:  132
# 9891.58140226471  step  133  of the epoch  0 the steps is:  133
# 7864.726049716704  step  134  of the epoch  0 the steps is:  134
# 6189.912727594194  step  135  of the epoch  0 the steps is:  135
# 4922.006547535228  step  136  of the epoch  0 the steps is:  136
# 5947.883707679074  step  137  of the epoch  0 the steps is:  137
# 7776.402179032096  step  138  of the epoch  0 the steps is:  138
# 8417.217492281976  step  139  of the epoch  0 the steps is:  139
# 9621.863775504466  step  140  of the epoch  0 the steps is:  140
# 8204.311849154905  step  141  of the epoch  0 the steps is:  141
# 9083.51218648035  step  142  of the epoch  0 the steps is:  142
# 11859.599904990977  step  143  of the epoch  0 the steps is:  143
# 8076.041660869707  step  144  of the epoch  0 the steps is:  144
# 8807.181300380264  step  145  of the epoch  0 the steps is:  145
# 7876.623699203412  step  146  of the epoch  0 the steps is:  146
# 10252.118747353574  step  147  of the epoch  0 the steps is:  147
# 7809.087214493026  step  148  of the epoch  0 the steps is:  148
# 8273.00570591572  step  149  of the epoch  0 the steps is:  149
# 8042.374675612784  step  150  of the epoch  0 the steps is:  150
# 6469.862798324656  step  151  of the epoch  0 the steps is:  151
# 6106.097401331168  step  152  of the epoch  0 the steps is:  152
# 5435.710937961228  step  153  of the epoch  0 the steps is:  153
# 5142.337308399907  step  154  of the epoch  0 the steps is:  154
# 4766.5226960249265  step  155  of the epoch  0 the steps is:  155
# 3477.496904795019  step  156  of the epoch  0 the steps is:  156
# 4081.4263176520826  step  157  of the epoch  0 the steps is:  157
# 5672.435259878035  step  158  of the epoch  0 the steps is:  158
# 5757.561751444263  step  159  of the epoch  0 the steps is:  159
# 8102.379425552477  step  160  of the epoch  0 the steps is:  160
# 7007.159753990147  step  161  of the epoch  0 the steps is:  161
# 8065.914852989954  step  162  of the epoch  0 the steps is:  162
# 8485.057907009548  step  163  of the epoch  0 the steps is:  163
# 8539.15593916651  step  164  of the epoch  0 the steps is:  164
# 12005.693656140154  step  165  of the epoch  0 the steps is:  165
# 10741.108270812594  step  166  of the epoch  0 the steps is:  166
# 7457.479656548784  step  167  of the epoch  0 the steps is:  167
# 7192.283188274947  step  168  of the epoch  0 the steps is:  168
# 5648.168802560364  step  169  of the epoch  0 the steps is:  169
# 7738.19657939102  step  170  of the epoch  0 the steps is:  170
# 8203.200551785227  step  171  of the epoch  0 the steps is:  171
# 7439.4080442296345  step  172  of the epoch  0 the steps is:  172
# 8750.714569659722  step  173  of the epoch  0 the steps is:  173
# 11561.026562773795  step  174  of the epoch  0 the steps is:  174
# 8040.12033619463  step  175  of the epoch  0 the steps is:  175
# 13951.57544823609  step  176  of the epoch  0 the steps is:  176
# 13405.815945575447  step  177  of the epoch  0 the steps is:  177
# 15368.970700443437  step  178  of the epoch  0 the steps is:  178
# 13879.959470865642  step  179  of the epoch  0 the steps is:  179
# 12199.618739651494  step  180  of the epoch  0 the steps is:  180
# 10638.425701637525  step  181  of the epoch  0 the steps is:  181
# 10011.605683998794  step  182  of the epoch  0 the steps is:  182
# 11650.06534864566  step  183  of the epoch  0 the steps is:  183
# 8928.116868527923  step  184  of the epoch  0 the steps is:  184
# 11349.64896563458  step  185  of the epoch  0 the steps is:  185
# 11435.917748986085  step  186  of the epoch  0 the steps is:  186
# 14161.919070527314  step  187  of the epoch  0 the steps is:  187
# 11819.753499769102  step  188  of the epoch  0 the steps is:  188
# 12415.752220274106  step  189  of the epoch  0 the steps is:  189
# 9301.29283934258  step  190  of the epoch  0 the steps is:  190
# 11835.894200698607  step  191  of the epoch  0 the steps is:  191
# 11376.85384614028  step  192  of the epoch  0 the steps is:  192
# 12261.934382668933  step  193  of the epoch  0 the steps is:  193
# 10943.751137127158  step  194  of the epoch  0 the steps is:  194
# 11064.826162116657  step  195  of the epoch  0 the steps is:  195
# 9708.48417051158  step  196  of the epoch  0 the steps is:  196
# 9593.06528394483  step  197  of the epoch  0 the steps is:  197
# 8725.010151524366  step  198  of the epoch  0 the steps is:  198
# 8631.039564665312  step  199  of the epoch  0 the steps is:  199
# 9549.335995747671  step  200  of the epoch  0 the steps is:  200
# 10209.997941306014  step  201  of the epoch  0 the steps is:  201
# 12052.280947386473  step  202  of the epoch  0 the steps is:  202
# 11519.111826677436  step  203  of the epoch  0 the steps is:  203
# 10840.89466745059  step  204  of the epoch  0 the steps is:  204
# 10026.536488857208  step  205  of the epoch  0 the steps is:  205
# 9631.025699471338  step  206  of the epoch  0 the steps is:  206
# 10631.64510124063  step  207  of the epoch  0 the steps is:  207
# 7260.353794215169  step  208  of the epoch  0 the steps is:  208
# 7620.795652098925  step  209  of the epoch  0 the steps is:  209
# 6099.487536482105  step  210  of the epoch  0 the steps is:  210
# 4193.168584878399  step  211  of the epoch  0 the steps is:  211
# 5073.836725637719  step  212  of the epoch  0 the steps is:  212
# 6680.162690166288  step  213  of the epoch  0 the steps is:  213
# 6516.355974088626  step  214  of the epoch  0 the steps is:  214
# 6129.580555871832  step  215  of the epoch  0 the steps is:  215
# 5143.438820107255  step  216  of the epoch  0 the steps is:  216
# 5255.670621640746  step  217  of the epoch  0 the steps is:  217
# 4581.304581647848  step  218  of the epoch  0 the steps is:  218
# 4000.664136634371  step  219  of the epoch  0 the steps is:  219
# 4383.308202312657  step  220  of the epoch  0 the steps is:  220
# 4521.411822189594  step  221  of the epoch  0 the steps is:  221
# 4877.339007718195  step  222  of the epoch  0 the steps is:  222
# 5455.249382430054  step  223  of the epoch  0 the steps is:  223
# 5166.164471580294  step  224  of the epoch  0 the steps is:  224
# 6708.2827701072365  step  225  of the epoch  0 the steps is:  225
# 7770.016968076574  step  226  of the epoch  0 the steps is:  226
# 7893.13425737519  step  227  of the epoch  0 the steps is:  227
# 6341.329364407004  step  228  of the epoch  0 the steps is:  228
# 6165.739445604078  step  229  of the epoch  0 the steps is:  229
# 6921.731623266576  step  230  of the epoch  0 the steps is:  230
# 4799.507854264268  step  231  of the epoch  0 the steps is:  231
# 7355.883892634842  step  232  of the epoch  0 the steps is:  232
# 4482.770035254844  step  233  of the epoch  0 the steps is:  233
# 4077.9103225635818  step  234  of the epoch  0 the steps is:  234
# 3825.3156114983303  step  235  of the epoch  0 the steps is:  235
# 3996.697511909932  step  236  of the epoch  0 the steps is:  236
# 3001.638043570326  step  237  of the epoch  0 the steps is:  237
# 3186.969917097047  step  238  of the epoch  0 the steps is:  238
# 3745.3219435430738  step  239  of the epoch  0 the steps is:  239
# 4321.432196192634  step  240  of the epoch  0 the steps is:  240
# 5980.233460845087  step  241  of the epoch  0 the steps is:  241
# 6500.264437348904  step  242  of the epoch  0 the steps is:  242
# 7439.028741947062  step  243  of the epoch  0 the steps is:  243
# 6589.706286007211  step  244  of the epoch  0 the steps is:  244
# 8290.277818244176  step  245  of the epoch  0 the steps is:  245
# 8482.92878989625  step  246  of the epoch  0 the steps is:  246
# 7946.689866969229  step  247  of the epoch  0 the steps is:  247
# 7732.823026306096  step  248  of the epoch  0 the steps is:  248
# 6811.135095234222  step  249  of the epoch  0 the steps is:  249
# 7395.26943337254  step  250  of the epoch  0 the steps is:  250
# 8633.184485666716  step  251  of the epoch  0 the steps is:  251
# 6174.148841998282  step  252  of the epoch  0 the steps is:  252
# 6098.041430498182  step  253  of the epoch  0 the steps is:  253
# 7200.3928414708835  step  254  of the epoch  0 the steps is:  254
# 8760.541494375097  step  255  of the epoch  0 the steps is:  255
# 9701.946216039341  step  256  of the epoch  0 the steps is:  256
# 8010.112824470323  step  257  of the epoch  0 the steps is:  257
# 7456.3936248183445  step  258  of the epoch  0 the steps is:  258
# 7990.302920313322  step  259  of the epoch  0 the steps is:  259
# 9037.986069449315  step  260  of the epoch  0 the steps is:  260
# 7820.537743128149  step  261  of the epoch  0 the steps is:  261
# 5790.49841025131  step  262  of the epoch  0 the steps is:  262
# 5396.484809618717  step  263  of the epoch  0 the steps is:  263
# 4027.8438205245748  step  264  of the epoch  0 the steps is:  264
# 4641.746782717187  step  265  of the epoch  0 the steps is:  265
# 3718.4311216087845  step  266  of the epoch  0 the steps is:  266
# 4097.222056876185  step  267  of the epoch  0 the steps is:  267
# 3975.007984710437  step  268  of the epoch  0 the steps is:  268
# 3809.045058052062  step  269  of the epoch  0 the steps is:  269
# 3599.6392413455524  step  270  of the epoch  0 the steps is:  270
# 4000.2342265222924  step  271  of the epoch  0 the steps is:  271
# 3645.803829434628  step  272  of the epoch  0 the steps is:  272
# 3871.667086538484  step  273  of the epoch  0 the steps is:  273
# 4683.187555831728  step  274  of the epoch  0 the steps is:  274
# 4758.810231621823  step  275  of the epoch  0 the steps is:  275
# 4580.072042604126  step  276  of the epoch  0 the steps is:  276
# 4437.349830768515  step  277  of the epoch  0 the steps is:  277
# 4551.289669700145  step  278  of the epoch  0 the steps is:  278
# 3446.940455631653  step  279  of the epoch  0 the steps is:  279
# 2614.4596487866547  step  280  of the epoch  0 the steps is:  280
# 4280.945447957392  step  281  of the epoch  0 the steps is:  281
# 6936.96691054761  step  282  of the epoch  0 the steps is:  282
# 7443.116848037919  step  283  of the epoch  0 the steps is:  283
# 4835.462843474811  step  284  of the epoch  0 the steps is:  284
# 4383.050251452  step  285  of the epoch  0 the steps is:  285
# 5084.310467449181  step  286  of the epoch  0 the steps is:  286
# 5796.286266865884  step  287  of the epoch  0 the steps is:  287
# 6664.299500114938  step  288  of the epoch  0 the steps is:  288
# 4233.532275080655  step  289  of the epoch  0 the steps is:  289
# 4577.522842877879  step  290  of the epoch  0 the steps is:  290
# 3407.607853501815  step  291  of the epoch  0 the steps is:  291
# 3991.3517199221965  step  292  of the epoch  0 the steps is:  292
# 5188.582864702717  step  293  of the epoch  0 the steps is:  293
# 5715.657334044672  step  294  of the epoch  0 the steps is:  294
# 6054.547906604422  step  295  of the epoch  0 the steps is:  295
# 6057.90870502741  step  296  of the epoch  0 the steps is:  296
# 6012.876090169357  step  297  of the epoch  0 the steps is:  297
# 7749.296146975485  step  298  of the epoch  0 the steps is:  298
# 7996.961383297516  step  299  of the epoch  0 the steps is:  299
# 6636.599617759724  step  300  of the epoch  0 the steps is:  300
# 7072.294815629668  step  301  of the epoch  0 the steps is:  301
# 7895.003900512125  step  302  of the epoch  0 the steps is:  302
# 9874.54368517766  step  303  of the epoch  0 the steps is:  303
# 9910.264682214583  step  304  of the epoch  0 the steps is:  304
# 11677.174218955353  step  305  of the epoch  0 the steps is:  305
# 10282.30621445899  step  306  of the epoch  0 the steps is:  306
# 11568.856029503168  step  307  of the epoch  0 the steps is:  307
# 11042.53055375786  step  308  of the epoch  0 the steps is:  308
# 11927.578766188537  step  309  of the epoch  0 the steps is:  309
# 12071.983484898952  step  310  of the epoch  0 the steps is:  310
# 12406.180556043368  step  311  of the epoch  0 the steps is:  311
# 10812.729780405447  step  312  of the epoch  0 the steps is:  312
# 10011.007995644948  step  313  of the epoch  0 the steps is:  313
# 8638.787475393412  step  314  of the epoch  0 the steps is:  314
# 7767.2758287635215  step  315  of the epoch  0 the steps is:  315
# 7020.350802949384  step  316  of the epoch  0 the steps is:  316
# 6764.725736347451  step  317  of the epoch  0 the steps is:  317
# 6374.376048431807  step  318  of the epoch  0 the steps is:  318
# 5965.829833206569  step  319  of the epoch  0 the steps is:  319
# 5026.30247923344  step  320  of the epoch  0 the steps is:  320
# 4843.905101912278  step  321  of the epoch  0 the steps is:  321
# 5388.34025489363  step  322  of the epoch  0 the steps is:  322
# 5475.9520920738105  step  323  of the epoch  0 the steps is:  323
# 5245.207989448479  step  324  of the epoch  0 the steps is:  324
# 5464.973486809225  step  325  of the epoch  0 the steps is:  325
# 5626.142824886393  step  326  of the epoch  0 the steps is:  326
# 5856.364305667315  step  327  of the epoch  0 the steps is:  327
# 5524.863184487014  step  328  of the epoch  0 the steps is:  328
# 4887.5127330555715  step  329  of the epoch  0 the steps is:  329
# 5144.1089236329035  step  330  of the epoch  0 the steps is:  330
# 4748.287133603381  step  331  of the epoch  0 the steps is:  331
# 4367.113624451407  step  332  of the epoch  0 the steps is:  332
# 4839.29736471046  step  333  of the epoch  0 the steps is:  333
# 5021.966081044881  step  334  of the epoch  0 the steps is:  334
# 4866.132437688719  step  335  of the epoch  0 the steps is:  335
# 4229.757659246813  step  336  of the epoch  0 the steps is:  336
# 3538.2688550394905  step  337  of the epoch  0 the steps is:  337
# 3737.326104031348  step  338  of the epoch  0 the steps is:  338
# 3311.998188619858  step  339  of the epoch  0 the steps is:  339
# 3889.1139538197913  step  340  of the epoch  0 the steps is:  340
# 4152.804929749961  step  341  of the epoch  0 the steps is:  341
# 6147.889033127483  step  342  of the epoch  0 the steps is:  342
# 8156.177898978815  step  343  of the epoch  0 the steps is:  343
# 10115.459227327941  step  344  of the epoch  0 the steps is:  344
# 9652.020478442104  step  345  of the epoch  0 the steps is:  345
# 7021.832423568689  step  346  of the epoch  0 the steps is:  346
# 6876.39104712837  step  347  of the epoch  0 the steps is:  347
# 9127.432275803701  step  348  of the epoch  0 the steps is:  348
# 9546.164831463444  step  349  of the epoch  0 the steps is:  349
# 6911.736431144822  step  350  of the epoch  0 the steps is:  350
# 8161.374640012486  step  351  of the epoch  0 the steps is:  351
# 0.09977777777777778
# 11316.611639678726  step  0  of the epoch  1 the steps is:  352
# 10595.396947430523  step  1  of the epoch  1 the steps is:  353
# 9739.86292781708  step  2  of the epoch  1 the steps is:  354
# 11044.106369610829  step  3  of the epoch  1 the steps is:  355
# 11617.775861068229  step  4  of the epoch  1 the steps is:  356
# 11053.97424245461  step  5  of the epoch  1 the steps is:  357
# 10459.475794489066  step  6  of the epoch  1 the steps is:  358
# 7577.020947857911  step  7  of the epoch  1 the steps is:  359
# 6911.987718642175  step  8  of the epoch  1 the steps is:  360
# 6448.297083373372  step  9  of the epoch  1 the steps is:  361
# 4805.51021157538  step  10  of the epoch  1 the steps is:  362
# 4590.236562284705  step  11  of the epoch  1 the steps is:  363
# 4515.018894839961  step  12  of the epoch  1 the steps is:  364
# 5090.477676150224  step  13  of the epoch  1 the steps is:  365
# 5644.572671345834  step  14  of the epoch  1 the steps is:  366
# 5284.307167626122  step  15  of the epoch  1 the steps is:  367
# 4722.584107031137  step  16  of the epoch  1 the steps is:  368
# 4203.76456406463  step  17  of the epoch  1 the steps is:  369
# 6894.701525035429  step  18  of the epoch  1 the steps is:  370
# 5817.5459858753375  step  19  of the epoch  1 the steps is:  371
# 7915.23022583292  step  20  of the epoch  1 the steps is:  372
# 6316.744810297374  step  21  of the epoch  1 the steps is:  373
# 6574.56214633261  step  22  of the epoch  1 the steps is:  374
# 9024.604662121163  step  23  of the epoch  1 the steps is:  375
# 6784.8941625986245  step  24  of the epoch  1 the steps is:  376
# 10446.215195695648  step  25  of the epoch  1 the steps is:  377
# 10599.196148298939  step  26  of the epoch  1 the steps is:  378
# 8519.001229681618  step  27  of the epoch  1 the steps is:  379
# 9128.974344280958  step  28  of the epoch  1 the steps is:  380
# 9517.60531200998  step  29  of the epoch  1 the steps is:  381
# 9483.06366193386  step  30  of the epoch  1 the steps is:  382
# 6798.8393948960365  step  31  of the epoch  1 the steps is:  383
# 7781.389894305866  step  32  of the epoch  1 the steps is:  384
# 6975.000169918602  step  33  of the epoch  1 the steps is:  385
# 8915.126215696157  step  34  of the epoch  1 the steps is:  386
# 11222.66694777937  step  35  of the epoch  1 the steps is:  387
# 8653.91243401374  step  36  of the epoch  1 the steps is:  388
# 8760.8930634563  step  37  of the epoch  1 the steps is:  389
# 8766.286173153541  step  38  of the epoch  1 the steps is:  390
# 7360.68262713241  step  39  of the epoch  1 the steps is:  391
# 7833.573155125547  step  40  of the epoch  1 the steps is:  392
# 5752.010957804503  step  41  of the epoch  1 the steps is:  393
# 5595.466155964251  step  42  of the epoch  1 the steps is:  394
# 4095.3306621115908  step  43  of the epoch  1 the steps is:  395
# 3809.7163569545482  step  44  of the epoch  1 the steps is:  396
# 3796.0266303582425  step  45  of the epoch  1 the steps is:  397
# 4677.023679756034  step  46  of the epoch  1 the steps is:  398
# 5586.388446969592  step  47  of the epoch  1 the steps is:  399
# 5076.1953749676195  step  48  of the epoch  1 the steps is:  400
# 5552.796498240602  step  49  of the epoch  1 the steps is:  401
# 6634.563125893888  step  50  of the epoch  1 the steps is:  402
# 6826.0511760310965  step  51  of the epoch  1 the steps is:  403
# 8709.47289428116  step  52  of the epoch  1 the steps is:  404
# 8961.721021771617  step  53  of the epoch  1 the steps is:  405
# 8819.255839965339  step  54  of the epoch  1 the steps is:  406
# 11103.627637428395  step  55  of the epoch  1 the steps is:  407
# 9194.921903991211  step  56  of the epoch  1 the steps is:  408
# 9527.18881157454  step  57  of the epoch  1 the steps is:  409
# 9178.360092152092  step  58  of the epoch  1 the steps is:  410
# 8741.164635598478  step  59  of the epoch  1 the steps is:  411
# 7050.464904074548  step  60  of the epoch  1 the steps is:  412
# 7136.525260338741  step  61  of the epoch  1 the steps is:  413
# 7464.40674157563  step  62  of the epoch  1 the steps is:  414
# 7066.986991748705  step  63  of the epoch  1 the steps is:  415
# 6195.998998447603  step  64  of the epoch  1 the steps is:  416
# 5816.489345406074  step  65  of the epoch  1 the steps is:  417
# 6763.325296927002  step  66  of the epoch  1 the steps is:  418
# 8193.044849657468  step  67  of the epoch  1 the steps is:  419
# 5930.720306556659  step  68  of the epoch  1 the steps is:  420
# 6641.0603046903225  step  69  of the epoch  1 the steps is:  421
# 7083.096877138853  step  70  of the epoch  1 the steps is:  422
# 7964.127110238649  step  71  of the epoch  1 the steps is:  423
# 6122.123971431683  step  72  of the epoch  1 the steps is:  424
# 6081.228164728865  step  73  of the epoch  1 the steps is:  425
# 7646.170079227075  step  74  of the epoch  1 the steps is:  426
# 6788.065700801023  step  75  of the epoch  1 the steps is:  427
# 9096.29177605032  step  76  of the epoch  1 the steps is:  428
# 8287.391807577933  step  77  of the epoch  1 the steps is:  429
# 7726.019990216866  step  78  of the epoch  1 the steps is:  430
# 11205.092854555782  step  79  of the epoch  1 the steps is:  431
# 11394.298625613965  step  80  of the epoch  1 the steps is:  432
# 10199.234682183964  step  81  of the epoch  1 the steps is:  433
# 13019.37189712578  step  82  of the epoch  1 the steps is:  434
# 12973.874360036796  step  83  of the epoch  1 the steps is:  435
# 13453.794596075984  step  84  of the epoch  1 the steps is:  436
# 12820.32367961459  step  85  of the epoch  1 the steps is:  437
# 11668.89836625701  step  86  of the epoch  1 the steps is:  438
# 11307.520125167772  step  87  of the epoch  1 the steps is:  439
# 11942.197879967876  step  88  of the epoch  1 the steps is:  440
# 11686.386570953939  step  89  of the epoch  1 the steps is:  441
# 14482.294258434635  step  90  of the epoch  1 the steps is:  442
# 15812.803575700505  step  91  of the epoch  1 the steps is:  443
# 14635.621595060535  step  92  of the epoch  1 the steps is:  444
# 16271.153094505647  step  93  of the epoch  1 the steps is:  445
# 18859.364934512134  step  94  of the epoch  1 the steps is:  446
# 16241.937566883324  step  95  of the epoch  1 the steps is:  447
# 13651.522829741332  step  96  of the epoch  1 the steps is:  448
# 15098.235662009163  step  97  of the epoch  1 the steps is:  449
# 15011.210850903317  step  98  of the epoch  1 the steps is:  450
# 13249.154963217072  step  99  of the epoch  1 the steps is:  451
# 13753.007806413809  step  100  of the epoch  1 the steps is:  452
# 10665.331861100116  step  101  of the epoch  1 the steps is:  453
# 12835.069484055364  step  102  of the epoch  1 the steps is:  454
# 11204.819892021129  step  103  of the epoch  1 the steps is:  455
# 8939.28535065901  step  104  of the epoch  1 the steps is:  456
# 7615.663687891167  step  105  of the epoch  1 the steps is:  457
# 9347.305234097083  step  106  of the epoch  1 the steps is:  458
# 7067.885406200225  step  107  of the epoch  1 the steps is:  459
# 8287.663229459242  step  108  of the epoch  1 the steps is:  460
# 6902.269090947184  step  109  of the epoch  1 the steps is:  461
# 9864.62131849643  step  110  of the epoch  1 the steps is:  462
# 8636.048764929954  step  111  of the epoch  1 the steps is:  463
# 10809.168134031728  step  112  of the epoch  1 the steps is:  464
# 9196.712016528802  step  113  of the epoch  1 the steps is:  465
# 9157.95278515782  step  114  of the epoch  1 the steps is:  466
# 10192.878971685448  step  115  of the epoch  1 the steps is:  467
# 9102.301759868758  step  116  of the epoch  1 the steps is:  468
# 10879.12126163605  step  117  of the epoch  1 the steps is:  469
# 9828.196425993121  step  118  of the epoch  1 the steps is:  470
# 8515.597687737012  step  119  of the epoch  1 the steps is:  471
# 6776.513220980378  step  120  of the epoch  1 the steps is:  472
# 7129.923930261173  step  121  of the epoch  1 the steps is:  473
# 5349.076889461045  step  122  of the epoch  1 the steps is:  474
# 5685.438572985263  step  123  of the epoch  1 the steps is:  475
# 3834.967883019145  step  124  of the epoch  1 the steps is:  476
# 4219.411413568227  step  125  of the epoch  1 the steps is:  477
# 5580.888843560146  step  126  of the epoch  1 the steps is:  478
# 5495.360806247942  step  127  of the epoch  1 the steps is:  479
# 4160.770986203277  step  128  of the epoch  1 the steps is:  480
# 4606.043033936913  step  129  of the epoch  1 the steps is:  481
# 5913.573116833833  step  130  of the epoch  1 the steps is:  482
# 4901.956966205293  step  131  of the epoch  1 the steps is:  483
# 5381.014572133622  step  132  of the epoch  1 the steps is:  484
# 5280.5396315913995  step  133  of the epoch  1 the steps is:  485
# 3816.350263780493  step  134  of the epoch  1 the steps is:  486
# 1933.4942073045631  step  135  of the epoch  1 the steps is:  487
# 2307.561882653584  step  136  of the epoch  1 the steps is:  488
# 3650.692881344322  step  137  of the epoch  1 the steps is:  489
# 5323.2405373686215  step  138  of the epoch  1 the steps is:  490
# 5381.571464522394  step  139  of the epoch  1 the steps is:  491
# 5528.749773107991  step  140  of the epoch  1 the steps is:  492
# 6232.253414269997  step  141  of the epoch  1 the steps is:  493
# 5625.4211074897175  step  142  of the epoch  1 the steps is:  494
# 9913.777103226195  step  143  of the epoch  1 the steps is:  495
# 8641.993665530477  step  144  of the epoch  1 the steps is:  496
# 9315.071207266006  step  145  of the epoch  1 the steps is:  497
# 6997.032294052804  step  146  of the epoch  1 the steps is:  498
# 9084.902631114848  step  147  of the epoch  1 the steps is:  499
# 7305.325799458515  step  148  of the epoch  1 the steps is:  500
# 9043.452651541853  step  149  of the epoch  1 the steps is:  501
# 11414.110008634754  step  150  of the epoch  1 the steps is:  502
# 12154.594850211462  step  151  of the epoch  1 the steps is:  503
# 13899.968854734863  step  152  of the epoch  1 the steps is:  504
# 18144.007989386802  step  153  of the epoch  1 the steps is:  505
# 13180.809397193687  step  154  of the epoch  1 the steps is:  506
# 13197.30393672044  step  155  of the epoch  1 the steps is:  507
# 15753.370255717584  step  156  of the epoch  1 the steps is:  508
# 12958.702128039524  step  157  of the epoch  1 the steps is:  509
# 12987.769449534453  step  158  of the epoch  1 the steps is:  510
# 10780.308436669417  step  159  of the epoch  1 the steps is:  511
# 7336.467957382941  step  160  of the epoch  1 the steps is:  512
# 6995.984572337322  step  161  of the epoch  1 the steps is:  513
# 7408.520616990867  step  162  of the epoch  1 the steps is:  514
# 8604.083454825522  step  163  of the epoch  1 the steps is:  515
# 9549.953435602843  step  164  of the epoch  1 the steps is:  516
# 7732.296315849803  step  165  of the epoch  1 the steps is:  517
# 6506.587490998316  step  166  of the epoch  1 the steps is:  518
# 7389.984106418901  step  167  of the epoch  1 the steps is:  519
# 6468.242805651645  step  168  of the epoch  1 the steps is:  520
# 5901.021348383181  step  169  of the epoch  1 the steps is:  521
# 6039.738871865446  step  170  of the epoch  1 the steps is:  522
# 5937.573754615647  step  171  of the epoch  1 the steps is:  523
# 5839.005457797595  step  172  of the epoch  1 the steps is:  524
# 6452.449217874632  step  173  of the epoch  1 the steps is:  525
# 7663.242879893168  step  174  of the epoch  1 the steps is:  526
# 6399.189847000182  step  175  of the epoch  1 the steps is:  527
# 7490.035357303739  step  176  of the epoch  1 the steps is:  528
# 8201.668181473453  step  177  of the epoch  1 the steps is:  529
# 9450.434670766588  step  178  of the epoch  1 the steps is:  530
# 8706.389607471086  step  179  of the epoch  1 the steps is:  531
# 9892.939933000098  step  180  of the epoch  1 the steps is:  532
# 6919.507784816431  step  181  of the epoch  1 the steps is:  533
# 7022.037133344778  step  182  of the epoch  1 the steps is:  534
# 6591.424517253518  step  183  of the epoch  1 the steps is:  535
# 6679.376115688308  step  184  of the epoch  1 the steps is:  536
# 5805.001182807979  step  185  of the epoch  1 the steps is:  537
# 4863.997983089474  step  186  of the epoch  1 the steps is:  538
# 7226.226837901932  step  187  of the epoch  1 the steps is:  539
# 8024.936402916786  step  188  of the epoch  1 the steps is:  540
# 8524.19039116877  step  189  of the epoch  1 the steps is:  541
# 10256.69184415553  step  190  of the epoch  1 the steps is:  542
# 10194.416190227395  step  191  of the epoch  1 the steps is:  543
# 10287.743344700664  step  192  of the epoch  1 the steps is:  544
# 7956.759315456614  step  193  of the epoch  1 the steps is:  545
# 8759.146600346947  step  194  of the epoch  1 the steps is:  546
# 5879.399363839166  step  195  of the epoch  1 the steps is:  547
# 7008.68880821534  step  196  of the epoch  1 the steps is:  548
# 8237.489575431591  step  197  of the epoch  1 the steps is:  549
# 8791.88556642873  step  198  of the epoch  1 the steps is:  550
# 8156.398712632982  step  199  of the epoch  1 the steps is:  551
# 10978.98282581824  step  200  of the epoch  1 the steps is:  552
# 7999.49258501855  step  201  of the epoch  1 the steps is:  553
# 10093.417680355858  step  202  of the epoch  1 the steps is:  554
# 12293.123854159869  step  203  of the epoch  1 the steps is:  555
# 11018.158857905095  step  204  of the epoch  1 the steps is:  556
# 12349.41542939711  step  205  of the epoch  1 the steps is:  557
# 11067.932420916142  step  206  of the epoch  1 the steps is:  558
# 11027.228599595524  step  207  of the epoch  1 the steps is:  559
# 9080.059093160817  step  208  of the epoch  1 the steps is:  560
# 9020.24058918039  step  209  of the epoch  1 the steps is:  561
# 9015.348964941613  step  210  of the epoch  1 the steps is:  562
# 7377.598738869976  step  211  of the epoch  1 the steps is:  563
# 4662.064342636014  step  212  of the epoch  1 the steps is:  564
# 4030.2666608340037  step  213  of the epoch  1 the steps is:  565
# 4151.197790559761  step  214  of the epoch  1 the steps is:  566
# 4697.620487101347  step  215  of the epoch  1 the steps is:  567
# 6103.581129012249  step  216  of the epoch  1 the steps is:  568
# 6270.707968605153  step  217  of the epoch  1 the steps is:  569
# 6137.978123864339  step  218  of the epoch  1 the steps is:  570
# 5929.8652650234  step  219  of the epoch  1 the steps is:  571
# 6512.954841306841  step  220  of the epoch  1 the steps is:  572
# 4488.317081896532  step  221  of the epoch  1 the steps is:  573
# 3704.9695372714627  step  222  of the epoch  1 the steps is:  574
# 3017.1015212939355  step  223  of the epoch  1 the steps is:  575
# 3383.4389655086234  step  224  of the epoch  1 the steps is:  576
# 3289.9167696079576  step  225  of the epoch  1 the steps is:  577
# 4314.2695347320805  step  226  of the epoch  1 the steps is:  578
# 5516.837722055599  step  227  of the epoch  1 the steps is:  579
# 7264.858274861181  step  228  of the epoch  1 the steps is:  580
# 8536.126671051783  step  229  of the epoch  1 the steps is:  581
# 7484.349529355625  step  230  of the epoch  1 the steps is:  582
# 8242.160488104237  step  231  of the epoch  1 the steps is:  583
# 7420.551809492945  step  232  of the epoch  1 the steps is:  584
# 7037.203084975954  step  233  of the epoch  1 the steps is:  585
# 5484.648698755286  step  234  of the epoch  1 the steps is:  586
# 4427.673462879114  step  235  of the epoch  1 the steps is:  587
# 4279.789144340183  step  236  of the epoch  1 the steps is:  588
# 4309.339278911069  step  237  of the epoch  1 the steps is:  589
# 4534.056523584396  step  238  of the epoch  1 the steps is:  590
# 5385.574514132847  step  239  of the epoch  1 the steps is:  591
# 5771.504871692899  step  240  of the epoch  1 the steps is:  592
# 4410.528032362494  step  241  of the epoch  1 the steps is:  593
# 4473.694703063772  step  242  of the epoch  1 the steps is:  594
# 4076.6024442024845  step  243  of the epoch  1 the steps is:  595
# 2893.8112373409613  step  244  of the epoch  1 the steps is:  596
# 2661.135924954918  step  245  of the epoch  1 the steps is:  597
# 3312.06282096166  step  246  of the epoch  1 the steps is:  598
# 2788.790873820531  step  247  of the epoch  1 the steps is:  599
# 4491.02917839725  step  248  of the epoch  1 the steps is:  600
# 4587.253683297736  step  249  of the epoch  1 the steps is:  601
# 5865.903179920893  step  250  of the epoch  1 the steps is:  602
# 7713.428840078437  step  251  of the epoch  1 the steps is:  603
# 6273.9478002578135  step  252  of the epoch  1 the steps is:  604
# 6736.600660923903  step  253  of the epoch  1 the steps is:  605
# 8674.727629847188  step  254  of the epoch  1 the steps is:  606
# 9957.237524231157  step  255  of the epoch  1 the steps is:  607
# 11775.128082658395  step  256  of the epoch  1 the steps is:  608
# 10599.587725808218  step  257  of the epoch  1 the steps is:  609
# 9094.12950001944  step  258  of the epoch  1 the steps is:  610
# 9387.218432632402  step  259  of the epoch  1 the steps is:  611
# 11805.160659329951  step  260  of the epoch  1 the steps is:  612
# 11353.971972701844  step  261  of the epoch  1 the steps is:  613
# 10654.75891155122  step  262  of the epoch  1 the steps is:  614
# 10488.795799391399  step  263  of the epoch  1 the steps is:  615
# 7781.801381776587  step  264  of the epoch  1 the steps is:  616
# 6128.174031887548  step  265  of the epoch  1 the steps is:  617
# 5556.524074691199  step  266  of the epoch  1 the steps is:  618
# 4880.575088780645  step  267  of the epoch  1 the steps is:  619
# 5040.087794434578  step  268  of the epoch  1 the steps is:  620
# 4547.771670634306  step  269  of the epoch  1 the steps is:  621
# 5079.793356415505  step  270  of the epoch  1 the steps is:  622
# 4875.177180607511  step  271  of the epoch  1 the steps is:  623
# 4503.095232660331  step  272  of the epoch  1 the steps is:  624
# 5373.350026966858  step  273  of the epoch  1 the steps is:  625
# 8444.75187929815  step  274  of the epoch  1 the steps is:  626
# 10871.235052656504  step  275  of the epoch  1 the steps is:  627
# 12272.601633209808  step  276  of the epoch  1 the steps is:  628
# 12181.807968572539  step  277  of the epoch  1 the steps is:  629
# 13349.36532623279  step  278  of the epoch  1 the steps is:  630
# 13568.147126520787  step  279  of the epoch  1 the steps is:  631
# 11931.789722323194  step  280  of the epoch  1 the steps is:  632
# 10454.555383087376  step  281  of the epoch  1 the steps is:  633
# 8026.856285049924  step  282  of the epoch  1 the steps is:  634
# 6807.857657762446  step  283  of the epoch  1 the steps is:  635
# 6646.80844020803  step  284  of the epoch  1 the steps is:  636
# 7155.09192108779  step  285  of the epoch  1 the steps is:  637
# 9124.034899599063  step  286  of the epoch  1 the steps is:  638
# 8286.648872837293  step  287  of the epoch  1 the steps is:  639
# 8865.622434462217  step  288  of the epoch  1 the steps is:  640
# 6731.731206950542  step  289  of the epoch  1 the steps is:  641
# 6799.404004038102  step  290  of the epoch  1 the steps is:  642
# 6472.217858272601  step  291  of the epoch  1 the steps is:  643
# 7861.706446179571  step  292  of the epoch  1 the steps is:  644
# 7536.376909670073  step  293  of the epoch  1 the steps is:  645
# 8464.746290926527  step  294  of the epoch  1 the steps is:  646
# 7018.665032092988  step  295  of the epoch  1 the steps is:  647
# 7349.932304801035  step  296  of the epoch  1 the steps is:  648
# 8713.442517145879  step  297  of the epoch  1 the steps is:  649
# 10207.059379521192  step  298  of the epoch  1 the steps is:  650
# 10669.4427261394  step  299  of the epoch  1 the steps is:  651
# 9287.241802873246  step  300  of the epoch  1 the steps is:  652
# 9013.283764565665  step  301  of the epoch  1 the steps is:  653
# 9193.834392688208  step  302  of the epoch  1 the steps is:  654
# 10389.861959651735  step  303  of the epoch  1 the steps is:  655
# 8965.253162230054  step  304  of the epoch  1 the steps is:  656
# 9016.195581193602  step  305  of the epoch  1 the steps is:  657
# 10620.810159114308  step  306  of the epoch  1 the steps is:  658
# 11364.813284093892  step  307  of the epoch  1 the steps is:  659
# 12258.49659310842  step  308  of the epoch  1 the steps is:  660
# 13407.40557235047  step  309  of the epoch  1 the steps is:  661
# 12820.05099238309  step  310  of the epoch  1 the steps is:  662
# 12070.05991286827  step  311  of the epoch  1 the steps is:  663
# 8741.058673076503  step  312  of the epoch  1 the steps is:  664
# 6136.065338904229  step  313  of the epoch  1 the steps is:  665
# 5672.38198657449  step  314  of the epoch  1 the steps is:  666
# 5147.198872823794  step  315  of the epoch  1 the steps is:  667
# 6047.173746307697  step  316  of the epoch  1 the steps is:  668
# 6254.522611665414  step  317  of the epoch  1 the steps is:  669
# 6335.774284720236  step  318  of the epoch  1 the steps is:  670
# 6919.2369027685745  step  319  of the epoch  1 the steps is:  671
# 6486.524455725229  step  320  of the epoch  1 the steps is:  672
# 6430.680606500841  step  321  of the epoch  1 the steps is:  673
# 6835.048392774515  step  322  of the epoch  1 the steps is:  674
# 7329.989834251176  step  323  of the epoch  1 the steps is:  675
# 5892.770690373753  step  324  of the epoch  1 the steps is:  676
# 6076.492306697388  step  325  of the epoch  1 the steps is:  677
# 4914.491401192132  step  326  of the epoch  1 the steps is:  678
# 4691.560442272772  step  327  of the epoch  1 the steps is:  679
# 4541.867961942426  step  328  of the epoch  1 the steps is:  680
# 4485.434791524021  step  329  of the epoch  1 the steps is:  681
# 4312.554746833287  step  330  of the epoch  1 the steps is:  682
# 3226.781277322737  step  331  of the epoch  1 the steps is:  683
# 4197.406881504427  step  332  of the epoch  1 the steps is:  684
# 4234.4885483968355  step  333  of the epoch  1 the steps is:  685
# 4588.274452127438  step  334  of the epoch  1 the steps is:  686
# 5431.434501994809  step  335  of the epoch  1 the steps is:  687
# 6452.33859795032  step  336  of the epoch  1 the steps is:  688
# 8228.337674761395  step  337  of the epoch  1 the steps is:  689
# 10142.246100010723  step  338  of the epoch  1 the steps is:  690
# 10133.76424252735  step  339  of the epoch  1 the steps is:  691
# 12276.051401967245  step  340  of the epoch  1 the steps is:  692
# 11275.455156871913  step  341  of the epoch  1 the steps is:  693
# 9697.058298744487  step  342  of the epoch  1 the steps is:  694
# 11002.563877619941  step  343  of the epoch  1 the steps is:  695
# 11765.88253364778  step  344  of the epoch  1 the steps is:  696
# 11091.585120291933  step  345  of the epoch  1 the steps is:  697
# 11101.353783011873  step  346  of the epoch  1 the steps is:  698
# 11169.748478439538  step  347  of the epoch  1 the steps is:  699
# 9845.955564127507  step  348  of the epoch  1 the steps is:  700
# 10442.079101227602  step  349  of the epoch  1 the steps is:  701
# 14263.957341453286  step  350  of the epoch  1 the steps is:  702
# 13099.777324795114  step  351  of the epoch  1 the steps is:  703
# 0.10057777777777778
# 13894.36475573355  step  0  of the epoch  2 the steps is:  704
# 12032.329577452016  step  1  of the epoch  2 the steps is:  705
# 13491.214855418719  step  2  of the epoch  2 the steps is:  706
# 10759.130452252983  step  3  of the epoch  2 the steps is:  707
# 11419.961718828665  step  4  of the epoch  2 the steps is:  708
# 11546.142430646676  step  5  of the epoch  2 the steps is:  709
# 10597.48857500872  step  6  of the epoch  2 the steps is:  710
# 8520.453571283779  step  7  of the epoch  2 the steps is:  711
# 8416.243658866046  step  8  of the epoch  2 the steps is:  712
# 7010.1683297821  step  9  of the epoch  2 the steps is:  713
# 5181.35447374808  step  10  of the epoch  2 the steps is:  714
# 5645.238000443897  step  11  of the epoch  2 the steps is:  715
# 5739.952055449183  step  12  of the epoch  2 the steps is:  716
# 5607.528208705413  step  13  of the epoch  2 the steps is:  717
# 6495.786718707356  step  14  of the epoch  2 the steps is:  718
# 5631.718935044375  step  15  of the epoch  2 the steps is:  719
# 4890.439659028734  step  16  of the epoch  2 the steps is:  720
# 6572.252762511907  step  17  of the epoch  2 the steps is:  721
# 5387.073674465799  step  18  of the epoch  2 the steps is:  722
# 5192.5542160508485  step  19  of the epoch  2 the steps is:  723
# 5014.728624710806  step  20  of the epoch  2 the steps is:  724
# 5923.909383821117  step  21  of the epoch  2 the steps is:  725
# 6718.882655094638  step  22  of the epoch  2 the steps is:  726
# 7947.234285978893  step  23  of the epoch  2 the steps is:  727
# 10966.02975224155  step  24  of the epoch  2 the steps is:  728
# 8009.23197616206  step  25  of the epoch  2 the steps is:  729
# 11349.158227436628  step  26  of the epoch  2 the steps is:  730
# 10962.54192142589  step  27  of the epoch  2 the steps is:  731
# 11241.968875532424  step  28  of the epoch  2 the steps is:  732
# 11298.269804931891  step  29  of the epoch  2 the steps is:  733
# 11322.235047400734  step  30  of the epoch  2 the steps is:  734
# 9370.640587777005  step  31  of the epoch  2 the steps is:  735
# 7374.366117425723  step  32  of the epoch  2 the steps is:  736
# 5257.51527577619  step  33  of the epoch  2 the steps is:  737
# 4656.498957576698  step  34  of the epoch  2 the steps is:  738
# 4420.3271275773395  step  35  of the epoch  2 the steps is:  739
# 3654.376400347992  step  36  of the epoch  2 the steps is:  740
# 4749.571547190205  step  37  of the epoch  2 the steps is:  741
# 5984.323245717713  step  38  of the epoch  2 the steps is:  742
# 7078.01141805285  step  39  of the epoch  2 the steps is:  743
# 9263.151460103196  step  40  of the epoch  2 the steps is:  744
# 9518.802571743407  step  41  of the epoch  2 the steps is:  745
# 8659.628701830185  step  42  of the epoch  2 the steps is:  746
# 9302.84597758198  step  43  of the epoch  2 the steps is:  747
# 9049.406667697725  step  44  of the epoch  2 the steps is:  748
# 6767.229877205671  step  45  of the epoch  2 the steps is:  749
# 7099.079055992339  step  46  of the epoch  2 the steps is:  750
# 8485.048850240793  step  47  of the epoch  2 the steps is:  751
# 7466.689957662302  step  48  of the epoch  2 the steps is:  752
# 7648.765314640319  step  49  of the epoch  2 the steps is:  753
# 6722.957361152678  step  50  of the epoch  2 the steps is:  754
# 5542.789031233471  step  51  of the epoch  2 the steps is:  755
# 5094.7099911956975  step  52  of the epoch  2 the steps is:  756
# 4618.432089314113  step  53  of the epoch  2 the steps is:  757
# 5602.030555896351  step  54  of the epoch  2 the steps is:  758
# 5301.600945997867  step  55  of the epoch  2 the steps is:  759
# 5103.640985608232  step  56  of the epoch  2 the steps is:  760
# 4880.394908733433  step  57  of the epoch  2 the steps is:  761
# 4770.555961746777  step  58  of the epoch  2 the steps is:  762
# 3570.331217959035  step  59  of the epoch  2 the steps is:  763
# 3101.9869134725627  step  60  of the epoch  2 the steps is:  764
# 4228.622181434966  step  61  of the epoch  2 the steps is:  765
# 4135.838465781049  step  62  of the epoch  2 the steps is:  766
# 3947.9957049175455  step  63  of the epoch  2 the steps is:  767
# 4189.17422907333  step  64  of the epoch  2 the steps is:  768
# 4372.233434918897  step  65  of the epoch  2 the steps is:  769
# 5086.313202890686  step  66  of the epoch  2 the steps is:  770
# 8314.248768780148  step  67  of the epoch  2 the steps is:  771
# 5243.437405112656  step  68  of the epoch  2 the steps is:  772
# 6163.371439281371  step  69  of the epoch  2 the steps is:  773
# 6591.950672044768  step  70  of the epoch  2 the steps is:  774
# 7452.897199733396  step  71  of the epoch  2 the steps is:  775
# 7306.421833079001  step  72  of the epoch  2 the steps is:  776
# 4963.373907401829  step  73  of the epoch  2 the steps is:  777
# 6598.233032249689  step  74  of the epoch  2 the steps is:  778
# 4465.253901419152  step  75  of the epoch  2 the steps is:  779
# 5370.232443042221  step  76  of the epoch  2 the steps is:  780
# 5154.060826013927  step  77  of the epoch  2 the steps is:  781
# 4381.179054072015  step  78  of the epoch  2 the steps is:  782
# 6327.407865418763  step  79  of the epoch  2 the steps is:  783
# 5920.456350042288  step  80  of the epoch  2 the steps is:  784
# 5458.952610047943  step  81  of the epoch  2 the steps is:  785
# 7280.504561594396  step  82  of the epoch  2 the steps is:  786
# 6597.386103285548  step  83  of the epoch  2 the steps is:  787
# 7551.327294150953  step  84  of the epoch  2 the steps is:  788
# 7911.620624248861  step  85  of the epoch  2 the steps is:  789
# 7832.547201472036  step  86  of the epoch  2 the steps is:  790
# 7319.668403062102  step  87  of the epoch  2 the steps is:  791
# 8083.225191395247  step  88  of the epoch  2 the steps is:  792
# 8368.286627574262  step  89  of the epoch  2 the steps is:  793
# 7119.3652830807105  step  90  of the epoch  2 the steps is:  794
# 8732.690495159473  step  91  of the epoch  2 the steps is:  795
# 9980.896691835625  step  92  of the epoch  2 the steps is:  796
# 8926.923530088896  step  93  of the epoch  2 the steps is:  797
# 11269.416117375331  step  94  of the epoch  2 the steps is:  798
# 8303.427977731662  step  95  of the epoch  2 the steps is:  799
# 10309.10990556756  step  96  of the epoch  2 the steps is:  800
# 9979.46837448496  step  97  of the epoch  2 the steps is:  801
# 12176.84568588144  step  98  of the epoch  2 the steps is:  802
# 12430.489498516341  step  99  of the epoch  2 the steps is:  803
# 9683.964443577446  step  100  of the epoch  2 the steps is:  804
# 9545.776820427687  step  101  of the epoch  2 the steps is:  805
# 9780.339521959126  step  102  of the epoch  2 the steps is:  806
# 10014.90795725891  step  103  of the epoch  2 the steps is:  807
# 9611.639944548442  step  104  of the epoch  2 the steps is:  808
# 10024.590186585894  step  105  of the epoch  2 the steps is:  809
# 8908.57459507578  step  106  of the epoch  2 the steps is:  810
# 6757.330536050778  step  107  of the epoch  2 the steps is:  811
# 8689.052559694539  step  108  of the epoch  2 the steps is:  812
# 9558.396562372185  step  109  of the epoch  2 the steps is:  813
# 9434.48036367415  step  110  of the epoch  2 the steps is:  814
# 8461.499072125436  step  111  of the epoch  2 the steps is:  815
# 9200.154690346782  step  112  of the epoch  2 the steps is:  816
# 7933.741158400201  step  113  of the epoch  2 the steps is:  817
# 10286.10165586886  step  114  of the epoch  2 the steps is:  818
# 7983.314772931942  step  115  of the epoch  2 the steps is:  819
# 7856.98077050458  step  116  of the epoch  2 the steps is:  820
# 8755.210652021178  step  117  of the epoch  2 the steps is:  821
# 8497.256058747656  step  118  of the epoch  2 the steps is:  822
# 8254.861325061584  step  119  of the epoch  2 the steps is:  823
# 9016.504933023907  step  120  of the epoch  2 the steps is:  824
# 9056.371857062135  step  121  of the epoch  2 the steps is:  825
# 7635.36100446201  step  122  of the epoch  2 the steps is:  826
# 6099.053981254763  step  123  of the epoch  2 the steps is:  827
# 4866.970103044965  step  124  of the epoch  2 the steps is:  828
# 5602.902070748763  step  125  of the epoch  2 the steps is:  829
# 7312.259089179829  step  126  of the epoch  2 the steps is:  830
# 8446.579621676992  step  127  of the epoch  2 the steps is:  831
# 9110.587279091525  step  128  of the epoch  2 the steps is:  832
# 9595.17330162405  step  129  of the epoch  2 the steps is:  833
# 11348.830109519775  step  130  of the epoch  2 the steps is:  834
# 9822.788157609728  step  131  of the epoch  2 the steps is:  835
# 9540.932972202949  step  132  of the epoch  2 the steps is:  836
# 9650.98897905292  step  133  of the epoch  2 the steps is:  837
# 9908.033067924038  step  134  of the epoch  2 the steps is:  838
# 7757.935953268612  step  135  of the epoch  2 the steps is:  839
# 8277.054940059916  step  136  of the epoch  2 the steps is:  840
# 10662.263461459259  step  137  of the epoch  2 the steps is:  841
# 10436.100733825846  step  138  of the epoch  2 the steps is:  842
# 10895.196721360198  step  139  of the epoch  2 the steps is:  843
# 11124.123919410846  step  140  of the epoch  2 the steps is:  844
# 9783.059675200835  step  141  of the epoch  2 the steps is:  845
# 8615.175259468511  step  142  of the epoch  2 the steps is:  846
# 11181.769075484006  step  143  of the epoch  2 the steps is:  847
# 7590.739930705404  step  144  of the epoch  2 the steps is:  848
# 7817.7015879649325  step  145  of the epoch  2 the steps is:  849
# 6646.031073228898  step  146  of the epoch  2 the steps is:  850
# 6089.672979234194  step  147  of the epoch  2 the steps is:  851
# 4348.561733729468  step  148  of the epoch  2 the steps is:  852
# 5493.966311019852  step  149  of the epoch  2 the steps is:  853
# 5530.44041489186  step  150  of the epoch  2 the steps is:  854
# 4694.405751568109  step  151  of the epoch  2 the steps is:  855
# 4625.72195688986  step  152  of the epoch  2 the steps is:  856
# 4025.3206766917456  step  153  of the epoch  2 the steps is:  857
# 2677.0462235671816  step  154  of the epoch  2 the steps is:  858
# 4081.4771780197107  step  155  of the epoch  2 the steps is:  859
# 5047.806957115243  step  156  of the epoch  2 the steps is:  860
# 5326.20265898497  step  157  of the epoch  2 the steps is:  861
# 7423.735933755219  step  158  of the epoch  2 the steps is:  862
# 9523.196808922405  step  159  of the epoch  2 the steps is:  863
# 12308.06893745294  step  160  of the epoch  2 the steps is:  864
# 11994.683104361231  step  161  of the epoch  2 the steps is:  865
# 11197.795425613107  step  162  of the epoch  2 the steps is:  866
# 11364.594970063903  step  163  of the epoch  2 the steps is:  867
# 9284.2594629615  step  164  of the epoch  2 the steps is:  868
# ...
# 823.1328462248093  step  118  of the epoch  49 the steps is:  17366
# 835.5575514763241  step  119  of the epoch  49 the steps is:  17367
# 828.2709478018813  step  120  of the epoch  49 the steps is:  17368
# 802.7890448243505  step  121  of the epoch  49 the steps is:  17369
# 837.9700253198389  step  122  of the epoch  49 the steps is:  17370
# 774.6615651263203  step  123  of the epoch  49 the steps is:  17371
# 848.31627862769  step  124  of the epoch  49 the steps is:  17372
# 874.9223973097547  step  125  of the epoch  49 the steps is:  17373
# 822.8916817823831  step  126  of the epoch  49 the steps is:  17374
# 815.0345666355639  step  127  of the epoch  49 the steps is:  17375
# 831.0631225189791  step  128  of the epoch  49 the steps is:  17376
# 880.7170601803261  step  129  of the epoch  49 the steps is:  17377
# 799.0821531995006  step  130  of the epoch  49 the steps is:  17378
# 829.7152263099892  step  131  of the epoch  49 the steps is:  17379
# 780.1852909662814  step  132  of the epoch  49 the steps is:  17380
# 848.3714844860697  step  133  of the epoch  49 the steps is:  17381
# 813.3707395373535  step  134  of the epoch  49 the steps is:  17382
# 794.5531472438441  step  135  of the epoch  49 the steps is:  17383
# 813.8355314532853  step  136  of the epoch  49 the steps is:  17384
# 775.2251115949912  step  137  of the epoch  49 the steps is:  17385
# 823.0840541856373  step  138  of the epoch  49 the steps is:  17386
# 820.2489248986863  step  139  of the epoch  49 the steps is:  17387
# 854.9536234547285  step  140  of the epoch  49 the steps is:  17388
# 817.5699132942585  step  141  of the epoch  49 the steps is:  17389
# 841.1865826104595  step  142  of the epoch  49 the steps is:  17390
# 896.3397308866339  step  143  of the epoch  49 the steps is:  17391
# 862.5470209566569  step  144  of the epoch  49 the steps is:  17392
# 856.1748926313672  step  145  of the epoch  49 the steps is:  17393
# 878.6081556558427  step  146  of the epoch  49 the steps is:  17394
# 843.3345161611933  step  147  of the epoch  49 the steps is:  17395
# 817.8977071761784  step  148  of the epoch  49 the steps is:  17396
# 747.0103201160235  step  149  of the epoch  49 the steps is:  17397
# 850.1298821973913  step  150  of the epoch  49 the steps is:  17398
# 857.1635960291953  step  151  of the epoch  49 the steps is:  17399
# 805.9323537399816  step  152  of the epoch  49 the steps is:  17400
# 899.2237714495957  step  153  of the epoch  49 the steps is:  17401
# 875.9770496034739  step  154  of the epoch  49 the steps is:  17402
# 851.2804768629196  step  155  of the epoch  49 the steps is:  17403
# 869.4772062697059  step  156  of the epoch  49 the steps is:  17404
# 753.0184109715469  step  157  of the epoch  49 the steps is:  17405
# 866.3233251288995  step  158  of the epoch  49 the steps is:  17406
# 817.8450826599319  step  159  of the epoch  49 the steps is:  17407
# 832.021919241686  step  160  of the epoch  49 the steps is:  17408
# 878.1399201491408  step  161  of the epoch  49 the steps is:  17409
# 819.3506003388717  step  162  of the epoch  49 the steps is:  17410
# 825.6680885708147  step  163  of the epoch  49 the steps is:  17411
# 767.3762530999019  step  164  of the epoch  49 the steps is:  17412
# 905.0608459873038  step  165  of the epoch  49 the steps is:  17413
# 768.5175108571258  step  166  of the epoch  49 the steps is:  17414
# 970.787597623636  step  167  of the epoch  49 the steps is:  17415
# 874.6936367325761  step  168  of the epoch  49 the steps is:  17416
# 904.1955558705482  step  169  of the epoch  49 the steps is:  17417
# 877.82931387031  step  170  of the epoch  49 the steps is:  17418
# 888.6521276854428  step  171  of the epoch  49 the steps is:  17419
# 896.1167059932416  step  172  of the epoch  49 the steps is:  17420
# 896.5767904267427  step  173  of the epoch  49 the steps is:  17421
# 937.1616783051371  step  174  of the epoch  49 the steps is:  17422
# 966.5372317569704  step  175  of the epoch  49 the steps is:  17423
# 885.687158195122  step  176  of the epoch  49 the steps is:  17424
# 925.2818487590653  step  177  of the epoch  49 the steps is:  17425
# 882.5167387936144  step  178  of the epoch  49 the steps is:  17426
# 881.784945009643  step  179  of the epoch  49 the steps is:  17427
# 811.0558972452399  step  180  of the epoch  49 the steps is:  17428
# 917.6047630148629  step  181  of the epoch  49 the steps is:  17429
# 832.842992101125  step  182  of the epoch  49 the steps is:  17430
# 877.095128409582  step  183  of the epoch  49 the steps is:  17431
# 885.4776402862174  step  184  of the epoch  49 the steps is:  17432
# 868.2703794856754  step  185  of the epoch  49 the steps is:  17433
# 846.7910315423621  step  186  of the epoch  49 the steps is:  17434
# 833.6750064771444  step  187  of the epoch  49 the steps is:  17435
# 910.5907609402709  step  188  of the epoch  49 the steps is:  17436
# 829.0604578496223  step  189  of the epoch  49 the steps is:  17437
# 870.0686123698017  step  190  of the epoch  49 the steps is:  17438
# 917.0759864671546  step  191  of the epoch  49 the steps is:  17439
# 932.4686095560899  step  192  of the epoch  49 the steps is:  17440
# 915.9222815408114  step  193  of the epoch  49 the steps is:  17441
# 845.4176728302614  step  194  of the epoch  49 the steps is:  17442
# 836.3235539108385  step  195  of the epoch  49 the steps is:  17443
# 816.8624647571194  step  196  of the epoch  49 the steps is:  17444
# 841.7917419449583  step  197  of the epoch  49 the steps is:  17445
# 867.1259343165805  step  198  of the epoch  49 the steps is:  17446
# 843.9133739753509  step  199  of the epoch  49 the steps is:  17447
# 836.3234571359774  step  200  of the epoch  49 the steps is:  17448
# 820.4823844104843  step  201  of the epoch  49 the steps is:  17449
# 824.1431933586492  step  202  of the epoch  49 the steps is:  17450
# 853.0678852236184  step  203  of the epoch  49 the steps is:  17451
# 806.5817726438313  step  204  of the epoch  49 the steps is:  17452
# 867.410626735704  step  205  of the epoch  49 the steps is:  17453
# 867.2787894764978  step  206  of the epoch  49 the steps is:  17454
# 792.8545427761179  step  207  of the epoch  49 the steps is:  17455
# 853.457621654555  step  208  of the epoch  49 the steps is:  17456
# 837.8982384022953  step  209  of the epoch  49 the steps is:  17457
# 947.8706106999675  step  210  of the epoch  49 the steps is:  17458
# 838.5481180950708  step  211  of the epoch  49 the steps is:  17459
# 911.6330159098375  step  212  of the epoch  49 the steps is:  17460
# 1020.4234647947857  step  213  of the epoch  49 the steps is:  17461
# 828.9199629575392  step  214  of the epoch  49 the steps is:  17462
# 879.2180967565693  step  215  of the epoch  49 the steps is:  17463
# 852.0517047507982  step  216  of the epoch  49 the steps is:  17464
# 823.4568051617949  step  217  of the epoch  49 the steps is:  17465
# 846.3823213103994  step  218  of the epoch  49 the steps is:  17466
# 806.3690894860837  step  219  of the epoch  49 the steps is:  17467
# 837.5509844707842  step  220  of the epoch  49 the steps is:  17468
# 819.384862246267  step  221  of the epoch  49 the steps is:  17469
# 830.2183128828098  step  222  of the epoch  49 the steps is:  17470
# 821.1063698249918  step  223  of the epoch  49 the steps is:  17471
# 789.739895156074  step  224  of the epoch  49 the steps is:  17472
# 796.3875677537924  step  225  of the epoch  49 the steps is:  17473
# 750.7993444714076  step  226  of the epoch  49 the steps is:  17474
# 778.4708227793833  step  227  of the epoch  49 the steps is:  17475
# 819.8813555671395  step  228  of the epoch  49 the steps is:  17476
# 762.9651611941291  step  229  of the epoch  49 the steps is:  17477
# 791.0109278902149  step  230  of the epoch  49 the steps is:  17478
# 822.7616841898009  step  231  of the epoch  49 the steps is:  17479
# 819.1553556178026  step  232  of the epoch  49 the steps is:  17480
# 816.1779323694951  step  233  of the epoch  49 the steps is:  17481
# 825.1928738494499  step  234  of the epoch  49 the steps is:  17482
# 813.8708228632629  step  235  of the epoch  49 the steps is:  17483
# 808.1802276263926  step  236  of the epoch  49 the steps is:  17484
# 794.8208789500459  step  237  of the epoch  49 the steps is:  17485
# 773.5804687939273  step  238  of the epoch  49 the steps is:  17486
# 761.9932404380465  step  239  of the epoch  49 the steps is:  17487
# 838.2681859098949  step  240  of the epoch  49 the steps is:  17488
# 797.9071849837758  step  241  of the epoch  49 the steps is:  17489
# 764.0837750688936  step  242  of the epoch  49 the steps is:  17490
# 809.2697546492614  step  243  of the epoch  49 the steps is:  17491
# 817.8822943809093  step  244  of the epoch  49 the steps is:  17492
# 774.6635981431482  step  245  of the epoch  49 the steps is:  17493
# 781.3660401618238  step  246  of the epoch  49 the steps is:  17494
# 851.7864508293073  step  247  of the epoch  49 the steps is:  17495
# 787.520107480873  step  248  of the epoch  49 the steps is:  17496
# 808.0558616754608  step  249  of the epoch  49 the steps is:  17497
# 792.6833141307181  step  250  of the epoch  49 the steps is:  17498
# 800.7045314907375  step  251  of the epoch  49 the steps is:  17499
# 799.9344663720399  step  252  of the epoch  49 the steps is:  17500
# 831.141494337226  step  253  of the epoch  49 the steps is:  17501
# 809.403249870832  step  254  of the epoch  49 the steps is:  17502
# 840.3200990751973  step  255  of the epoch  49 the steps is:  17503
# 801.9198706854631  step  256  of the epoch  49 the steps is:  17504
# 851.7036210417683  step  257  of the epoch  49 the steps is:  17505
# 820.3394516858763  step  258  of the epoch  49 the steps is:  17506
# 772.2051051337414  step  259  of the epoch  49 the steps is:  17507
# 820.1688418983449  step  260  of the epoch  49 the steps is:  17508
# 904.8152721837066  step  261  of the epoch  49 the steps is:  17509
# 863.0283426034473  step  262  of the epoch  49 the steps is:  17510
# 785.485956272772  step  263  of the epoch  49 the steps is:  17511
# 813.058468435121  step  264  of the epoch  49 the steps is:  17512
# 821.6879318433297  step  265  of the epoch  49 the steps is:  17513
# 803.3294355730841  step  266  of the epoch  49 the steps is:  17514
# 867.8105822930224  step  267  of the epoch  49 the steps is:  17515
# 830.3654284872358  step  268  of the epoch  49 the steps is:  17516
# 852.502102289184  step  269  of the epoch  49 the steps is:  17517
# 864.1229010645259  step  270  of the epoch  49 the steps is:  17518
# 850.2510991498901  step  271  of the epoch  49 the steps is:  17519
# 824.8103372875748  step  272  of the epoch  49 the steps is:  17520
# 793.2382478904639  step  273  of the epoch  49 the steps is:  17521
# 811.4824660418303  step  274  of the epoch  49 the steps is:  17522
# 890.5412999579497  step  275  of the epoch  49 the steps is:  17523
# 810.6610191639465  step  276  of the epoch  49 the steps is:  17524
# 794.6436567830883  step  277  of the epoch  49 the steps is:  17525
# 832.698937001494  step  278  of the epoch  49 the steps is:  17526
# 845.315335370678  step  279  of the epoch  49 the steps is:  17527
# 851.8828585641937  step  280  of the epoch  49 the steps is:  17528
# 837.7205762722464  step  281  of the epoch  49 the steps is:  17529
# 850.6754517762984  step  282  of the epoch  49 the steps is:  17530
# 901.345512532858  step  283  of the epoch  49 the steps is:  17531
# 871.8956193409888  step  284  of the epoch  49 the steps is:  17532
# 845.590336599799  step  285  of the epoch  49 the steps is:  17533
# 842.3894430988278  step  286  of the epoch  49 the steps is:  17534
# 921.8290082209514  step  287  of the epoch  49 the steps is:  17535
# 1008.3317854660712  step  288  of the epoch  49 the steps is:  17536
# 868.4562783601518  step  289  of the epoch  49 the steps is:  17537
# 994.9535994818875  step  290  of the epoch  49 the steps is:  17538
# 881.1281138491706  step  291  of the epoch  49 the steps is:  17539
# 891.1123471924395  step  292  of the epoch  49 the steps is:  17540
# 778.257748362239  step  293  of the epoch  49 the steps is:  17541
# 777.8678378775178  step  294  of the epoch  49 the steps is:  17542
# 1023.6713684053537  step  295  of the epoch  49 the steps is:  17543
# 814.5747891853155  step  296  of the epoch  49 the steps is:  17544
# 851.7659887933602  step  297  of the epoch  49 the steps is:  17545
# 943.4298737894964  step  298  of the epoch  49 the steps is:  17546
# 972.0442239221187  step  299  of the epoch  49 the steps is:  17547
# 1099.7806910908953  step  300  of the epoch  49 the steps is:  17548
# 1030.0332847702098  step  301  of the epoch  49 the steps is:  17549
# 945.3398088208216  step  302  of the epoch  49 the steps is:  17550
# 956.6876491154621  step  303  of the epoch  49 the steps is:  17551
# 942.111922397085  step  304  of the epoch  49 the steps is:  17552
# 909.8132774354654  step  305  of the epoch  49 the steps is:  17553
# 951.6373772215918  step  306  of the epoch  49 the steps is:  17554
# 1040.105817081453  step  307  of the epoch  49 the steps is:  17555
# 873.6120977328868  step  308  of the epoch  49 the steps is:  17556
# 980.2298467566337  step  309  of the epoch  49 the steps is:  17557
# 947.3605194914201  step  310  of the epoch  49 the steps is:  17558
# 957.303602143488  step  311  of the epoch  49 the steps is:  17559
# 994.26866655673  step  312  of the epoch  49 the steps is:  17560
# 916.6280185104272  step  313  of the epoch  49 the steps is:  17561
# 935.0277882515418  step  314  of the epoch  49 the steps is:  17562
# 886.4738418555194  step  315  of the epoch  49 the steps is:  17563
# 936.5866205321138  step  316  of the epoch  49 the steps is:  17564
# 896.6981950601945  step  317  of the epoch  49 the steps is:  17565
# 819.0459093150314  step  318  of the epoch  49 the steps is:  17566
# 888.9123295265026  step  319  of the epoch  49 the steps is:  17567
# 936.6954330566516  step  320  of the epoch  49 the steps is:  17568
# 846.752129070403  step  321  of the epoch  49 the steps is:  17569
# 867.4208810687343  step  322  of the epoch  49 the steps is:  17570
# 898.0564141691219  step  323  of the epoch  49 the steps is:  17571
# 889.8634515545526  step  324  of the epoch  49 the steps is:  17572
# 849.1309042869602  step  325  of the epoch  49 the steps is:  17573
# 878.4908643892899  step  326  of the epoch  49 the steps is:  17574
# 845.5019709416828  step  327  of the epoch  49 the steps is:  17575
# 812.1610560357395  step  328  of the epoch  49 the steps is:  17576
# 827.585393625041  step  329  of the epoch  49 the steps is:  17577
# 799.1596014051448  step  330  of the epoch  49 the steps is:  17578
# 846.3520935044016  step  331  of the epoch  49 the steps is:  17579
# 802.3680349976086  step  332  of the epoch  49 the steps is:  17580
# 851.155494433061  step  333  of the epoch  49 the steps is:  17581
# 809.0417856332565  step  334  of the epoch  49 the steps is:  17582
# 835.4614656857891  step  335  of the epoch  49 the steps is:  17583
# 873.0324250281903  step  336  of the epoch  49 the steps is:  17584
# 853.071466061451  step  337  of the epoch  49 the steps is:  17585
# 879.739452604755  step  338  of the epoch  49 the steps is:  17586
# 867.1674461327495  step  339  of the epoch  49 the steps is:  17587
# 932.1255929967621  step  340  of the epoch  49 the steps is:  17588
# 859.981219665962  step  341  of the epoch  49 the steps is:  17589
# 861.59353152314  step  342  of the epoch  49 the steps is:  17590
# 803.9972274622426  step  343  of the epoch  49 the steps is:  17591
# 962.5634673062416  step  344  of the epoch  49 the steps is:  17592
# 839.2967008761987  step  345  of the epoch  49 the steps is:  17593
# 872.5218739805188  step  346  of the epoch  49 the steps is:  17594
# 900.3037469189521  step  347  of the epoch  49 the steps is:  17595
# 807.3155016112706  step  348  of the epoch  49 the steps is:  17596
# 968.613950864208  step  349  of the epoch  49 the steps is:  17597
# 914.5416554112671  step  350  of the epoch  49 the steps is:  17598
# 968.4795484258526  step  351  of the epoch  49 the steps is:  17599
# 0.14731111111111111
# time of train : 2944.5841841670003

# %%
MyNetwork.Test_Network(Test_data, Test_label)
MyNetwork.Test_Network(Train_data, Train_label)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:28: RuntimeWarning: overflow encountered in cosh
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:28: RuntimeWarning: overflow encountered in power
# 0.1502
# 0.14731111111111111
# 0.14731111111111111

# %%
plt.plot(np.arange(1,len(MyNetwork.accuracy_graph_epoch)+1), MyNetwork.accuracy_graph_epoch)
plt.ylabel('Accuracy')
plt.xlabel("number epoch")
plt.grid(True)
plt.show()

# %%
plt.plot(np.arange(1,len(MyNetwork.loss_graph)+1), MyNetwork.loss_graph)
plt.ylabel('loss')
plt.xlabel("number steps")
plt.grid(True)
plt.show()
