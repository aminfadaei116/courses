# %% [markdown]
# At first we need to mount the drive so can have access to the data in the drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Add all The libraries that you need here

# %%
import pandas as pd
import numpy as np
from numpy import linalg as LA

# %% [markdown]
# Load all the data here

# %%
Test_data = pd.read_csv('/content/drive/My Drive/Deep Learning Course Spring 99/DataSets/Fashion-MNIST/testData.csv', header = None)
Test_label = pd.read_csv('/content/drive/My Drive/Deep Learning Course Spring 99/DataSets/Fashion-MNIST/testLabels.csv', header = None)
Train_data = pd.read_csv('/content/drive/My Drive/Deep Learning Course Spring 99/DataSets/Fashion-MNIST/trainData.csv', header = None)
Train_label = pd.read_csv('/content/drive/My Drive/Deep Learning Course Spring 99/DataSets/Fashion-MNIST/trainLabels.csv', header = None)

# %%
Test_data_np = Test_data.to_numpy()
Test_label_np = Test_label.to_numpy()
Train_data_np = Train_data.to_numpy()
Train_label_np = Train_label.to_numpy()

# %% [markdown]
# Here we define The covariance matrix

# %%
def calc_cov(data_set, mean):
    res = np.zeros([data_set.shape[1],data_set.shape[1]])
    for i in range(data_set.shape[0]):
        vect = np.subtract(data_set[i], mean)
        vect = np.array([vect])
        res += np.matmul(vect.T, vect)

    return res/(data_set.shape[0]-1)

# %% [markdown]
# Calculate the Mean and Covariance

# %%
Data_avg = np.mean(Train_data_np, axis = 0)
Data_cov = calc_cov(Train_data_np, Data_avg)

# %%
EigenValues, EigenVectors = LA.eigh(Data_cov)

# %%
def is_sorted(a):
    for i in range(a.size-1):
         if a[i+1] < a[i] :
               return False
    return True

# %%
print(is_sorted(eigenvalues))
# Out:
# True

# %% [markdown]
# The Eigen Values and Vectors are calculated

# %%
New_EigenValues = EigenValues[-128:]
New_EigenVectors = EigenVectors[:,-128:]

# %% [markdown]
# We now have our new DataSet with reduced dimension

# %%
New_Train_Data = np.matmul(Train_data_np, New_EigenVectors)
New_Test_Data = np.matmul(Test_data_np, New_EigenVectors)

# %%
Train_df = pd.DataFrame(New_Train_Data)
Test_df = pd.DataFrame(New_Test_Data)

# %%
Train_df.to_csv("/content/drive/My Drive/Deep Learning Course Spring 99/DataSets/Fashion-MNIST/Reduced_Train_Data.csv", index=False, header=False)
Test_df.to_csv("/content/drive/My Drive/Deep Learning Course Spring 99/DataSets/Fashion-MNIST/Reduced_Test_Data.csv", index=False, header=False)
