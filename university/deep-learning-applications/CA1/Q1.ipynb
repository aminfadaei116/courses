# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %% [markdown]
# We define the needed libraries here

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from time import process_time

# %% [markdown]
# Load all the data here

# %%
Test_data = pd.read_csv('/content/drive/My Drive/Deep Learning Course Spring 99/DataSets/Fashion-MNIST/Reduced_Test_Data.csv', header = None)
Test_label = pd.read_csv('/content/drive/My Drive/Deep Learning Course Spring 99/DataSets/Fashion-MNIST/testLabels.csv', header = None)
Train_data = pd.read_csv('/content/drive/My Drive/Deep Learning Course Spring 99/DataSets/Fashion-MNIST/Reduced_Train_Data.csv', header = None)
Train_label = pd.read_csv('/content/drive/My Drive/Deep Learning Course Spring 99/DataSets/Fashion-MNIST/trainLabels.csv', header = None)

# %%
Test_data = Test_data.to_numpy()
Test_label = Test_label.to_numpy()
Train_data = Train_data.to_numpy()
Train_label = Train_label.to_numpy()

# %% [markdown]
# Normalizing Data

# %%
maxD = np.max(Train_data, axis=0)
minD = np.min(Train_data, axis=0)
delta = maxD - minD
Train_data = Train_data - minD
Test_data = Test_data - minD
Train_data = 2 * (Train_data/delta) - 1
Test_data = 2 * (Test_data/delta) - 1

# %% [markdown]
# We have Numpy data
# And we are going define some functions

# %%
def relu(x):
  return np.maximum(x, np.zeros_like(x))

def Cal_accuracy(True_label, Estimated_label):
  return np.count_nonzero(np.transpose(True_label)==np.array(Estimated_label))/True_label.size

def step(x):
  return 1*(x > np.zeros_like(x))

def encode(vect, idx):
  temp = step(vect)
  temp[idx] = 0
  n = np.sum(temp)
  for i in range(len(temp)):
    if temp[i] == 1:
      temp[i] = -1
  temp[idx] = n
  return temp

# %% [markdown]
# Here we define the class network

# %%
class Network:
  def __init__(self, input_node, hidden_layer, hidden_node, output_node):
    self.number_input_node = input_node
    self.number_hidden_layer = hidden_layer
    self.number_hidden_node = hidden_node
    self.number_class_output = output_node
    self.weight = {}
    self.layer = {}
    self.batch_data = {}
    self.batch_label = {}
    self.diff_weight = {}
    self.score = []
    self.result = []
    self.init_weight()
    self.loss = []
    self.back_prob_output = []
    for i in range(self.number_hidden_layer + 1):
      self.diff_weight["w" + str(i) + "_prev"] = 0
      self.diff_weight["b" + str(i) + "_prev"] = 0
    self.momentum = 0.9
    self.learning_rate = 0.001
    self.number_turn = 100
    self.batchS = 128
    self.accuracy_graph = []
    self.loss_graph = []
    self.accuracy_graph_epoch = []

  def set_turn(self, x):
    self.number_turn = x

  def set_learning_rate(self, x):
    self.learning_rate = x

  def set_batch_size(self, x):
    self.batchS = x
  
  def load_weights(self):
    for i in range(self.number_hidden_layer + 1):
      self.weight["w" + str(i)] = (pd.read_csv("/content/drive/My Drive/Deep Learning Course Spring 99/DataSets/Fashion-MNIST/w" + str(i) + ".csv", header=None)).to_numpy()
      self.weight["b" + str(i)] = (pd.read_csv("/content/drive/My Drive/Deep Learning Course Spring 99/DataSets/Fashion-MNIST/b" + str(i) + ".csv", header=None)).to_numpy()

  def init_weight(self):
    self.weight["w0"] = np.random.normal(loc=0, scale=0.14, size=(self.number_hidden_node[0], self.number_input_node))
    self.weight["b0"] = np.random.normal(loc=0, scale=0.14, size=(self.number_hidden_node[0], 1))
    for i in range(self.number_hidden_layer - 1):
      self.weight["w" + str(i+1)] = (np.random.normal(loc=0, scale=0.14, size=(self.number_hidden_node[i+1], self.number_hidden_node[i])))
      self.weight["b" + str(i+1)] = (np.random.normal(loc=0, scale=0.14, size=(self.number_hidden_node[i+1], 1)))
    self.weight["w" + str(self.number_hidden_layer)] = np.random.normal(loc=0, scale=0.14, size=(self.number_class_output, self.number_hidden_node[self.number_hidden_layer-1]))
    self.weight["b" + str(self.number_hidden_layer)] = np.random.normal(loc=0, scale=0.14, size=(self.number_class_output, 1))
    
  def forward(self, data):
    self.layer.clear()
    self.layer["input"] = data
    if len(data) == data.size:
      self.layer["z0"] = (np.matmul(self.weight["w0"],np.transpose(data))).reshape((len(MyNetwork.weight["w0"]),1))
    else:
      self.layer["z0"] = (np.matmul(self.weight["w0"], np.transpose(data)))
    self.layer["z0"] = np.add(self.layer["z0"], self.weight["b0"])
    self.layer["r0"] = relu(self.layer["z0"])
    self.layer["s0"] = step(self.layer["z0"])
    for i in range(self.number_hidden_layer - 1):
      self.layer["z" + str(i + 1)] = np.matmul(self.weight["w" + str(i + 1)], self.layer["r" + str(i)])
      self.layer["z" + str(i + 1)] = np.add(self.layer["z" + str(i + 1)], self.weight["b" + str(i + 1)])
      self.layer["r" + str(i + 1)] = relu(self.layer["z" + str(i + 1)])
      self.layer["s" + str(i + 1)] = step(self.layer["z" + str(i + 1)])
    self.layer["z" + str(self.number_hidden_layer)] = np.matmul(self.weight["w" + str(self.number_hidden_layer)], self.layer["r" + str(self.number_hidden_layer - 1)])
    self.layer["z" + str(self.number_hidden_layer)] = np.add(self.layer["z" + str(self.number_hidden_layer)], self.weight["b" + str(self.number_hidden_layer)])
    self.layer["r" + str(self.number_hidden_layer)] = relu(self.layer["z" + str(self.number_hidden_layer)])
    self.layer["s" + str(self.number_hidden_layer)] = step(self.layer["z" + str(self.number_hidden_layer)])
    self.score = self.layer["r" + str(self.number_hidden_layer)]
    temp = self.decide(self.score)
    return temp
  
  def decide(self, data):
    self.result = np.argmax(data, axis=0)
    return self.result

  def cal_loss(self, label):
    self.loss.clear()
    self.back_prob_output = []
    temp = np.transpose(self.score)
    for i in range(len(label)):
      self.loss.append(np.sum(relu(temp[i] - temp[i][label[i]] + 1))-1)# inja ro bayad taghir bedi
      self.back_prob_output.append(encode((temp[i] - temp[i][label[i]] + 1), label[i]))
    self.back_prob_output = (np.transpose(self.back_prob_output))/len(label)
    total_loss = np.sum(self.loss)/len(self.loss)
    self.loss_graph.append(total_loss)
    return total_loss

  def batching(self, data, label):
    batch_size = self.batchS
    if len(data) == data.size:
      batch[0] = data
      return
    for i in range(int(len(data)/batch_size)):
      self.batch_data[i] = data[i*batch_size:(i+1)*batch_size]
      self.batch_label[i] = label[i*batch_size:(i+1)*batch_size]
    if len(data)%batch_size != 0:
      self.batch_data[int(len(data)/batch_size)] = data[int(len(data)/batch_size)*batch_size:len(data)]
      self.batch_label[int(len(data)/batch_size)] = label[int(len(data)/batch_size)*batch_size:len(data)]

  def back_prob(self):
    temp = np.multiply(self.back_prob_output, self.layer["s" + str(self.number_hidden_layer)])
    for i in range(self.number_hidden_layer):
      self.diff_weight["w" + str(self.number_hidden_layer - i)] = np.matmul(temp, np.transpose(self.layer["r"+ str(self.number_hidden_layer-1-i)]))
      self.diff_weight["b" + str(self.number_hidden_layer - i)] = np.matmul(temp, np.ones((len(temp[0]), 1)))
      temp = np.matmul(np.transpose(self.weight["w" + str(self.number_hidden_layer - i)]), temp)
      temp = np.multiply(self.layer["s" + str(self.number_hidden_layer - i - 1)], temp)
    self.diff_weight["w0"] = np.matmul(temp, self.layer["input"])
    self.diff_weight["b0"] = np.matmul(temp, np.ones((len(temp[0]), 1)))

    for i in range(self.number_hidden_layer + 1):
      self.diff_weight["w" + str(i) + "_prev"] = ((1 - self.momentum) * self.diff_weight["w" + str(i)] + self.momentum * self.diff_weight["w" + str(i) + "_prev"])
      self.diff_weight["b" + str(i) + "_prev"] = ((1 - self.momentum) * self.diff_weight["b" + str(i)] + self.momentum * self.diff_weight["b" + str(i) + "_prev"])

    for i in range(self.number_hidden_layer + 1):
      self.weight["w" + str(i)] = self.weight["w" + str(i)] + self.diff_weight["w" + str(i) + "_prev"] * self.learning_rate
      self.weight["b" + str(i)] = self.weight["b" + str(i)] + self.diff_weight["b" + str(i) + "_prev"] * self.learning_rate

  def Train_Network(self, data, label):
    epoch = 0
    self.accuracy_graph_epoch.append((self.Test_Network(data, label)))
    for j in range(self.number_turn):
      self.batching(data, label)
      for i in range(len(self.batch_data)):
        self.forward(self.batch_data[i])
        self.accuracy_graph.append(Cal_accuracy(self.batch_label[i], self.forward(self.batch_data[i])))
        print(self.cal_loss(self.batch_label[i]), " step ", i," of the epoch ", j , "the steps is: ", epoch)
        self.back_prob()
        epoch += 1
      self.accuracy_graph_epoch.append((self.Test_Network(data, label)))

  def Test_Network(self, data, label):
    if(len(data) == data.size):
      temp = self.batchS
      self.batchS = 1
      print(Cal_accuracy(label, MyNetwork.forward(data)))
      self.batchS = temp
    else:
      print(Cal_accuracy(label, MyNetwork.forward(data)))
    return (Cal_accuracy(label, MyNetwork.forward(data)))

# %% [markdown]
# We are going to define a Network call MyNetwork and in order to save it's weights we are not going to touch it

# %%
MyNetwork = Network(128,1,[150] ,10)
MyNetwork.set_learning_rate(0.005)
MyNetwork.set_turn(5)
MyNetwork.set_batch_size(1)
start = process_time()
MyNetwork.Train_Network(Train_data, Train_label)
print('time of train :', process_time()-start)
# Out:
# Streaming output truncated to the last 5000 lines.
# 1.1827829007893915  step  55003  of the epoch  4 the steps is:  295003
# 0.0  step  55004  of the epoch  4 the steps is:  295004
# 0.0  step  55005  of the epoch  4 the steps is:  295005
# 0.0  step  55006  of the epoch  4 the steps is:  295006
# 0.0  step  55007  of the epoch  4 the steps is:  295007
# 0.0  step  55008  of the epoch  4 the steps is:  295008
# 0.0  step  55009  of the epoch  4 the steps is:  295009
# 2.36993903767077  step  55010  of the epoch  4 the steps is:  295010
# 0.0  step  55011  of the epoch  4 the steps is:  295011
# 0.0  step  55012  of the epoch  4 the steps is:  295012
# 3.4764912566690214  step  55013  of the epoch  4 the steps is:  295013
# 0.0  step  55014  of the epoch  4 the steps is:  295014
# 0.0  step  55015  of the epoch  4 the steps is:  295015
# 0.0  step  55016  of the epoch  4 the steps is:  295016
# 2.4474038315740003  step  55017  of the epoch  4 the steps is:  295017
# 7.414366816240774  step  55018  of the epoch  4 the steps is:  295018
# 2.4326109138974026  step  55019  of the epoch  4 the steps is:  295019
# 0.0  step  55020  of the epoch  4 the steps is:  295020
# 0.0  step  55021  of the epoch  4 the steps is:  295021
# 0.0  step  55022  of the epoch  4 the steps is:  295022
# 3.5381669814076684  step  55023  of the epoch  4 the steps is:  295023
# 0.0  step  55024  of the epoch  4 the steps is:  295024
# 0.0  step  55025  of the epoch  4 the steps is:  295025
# 0.6937622421393277  step  55026  of the epoch  4 the steps is:  295026
# 0.0  step  55027  of the epoch  4 the steps is:  295027
# 0.0  step  55028  of the epoch  4 the steps is:  295028
# 0.7276443205493486  step  55029  of the epoch  4 the steps is:  295029
# 0.0  step  55030  of the epoch  4 the steps is:  295030
# 0.0  step  55031  of the epoch  4 the steps is:  295031
# 0.0  step  55032  of the epoch  4 the steps is:  295032
# 0.0  step  55033  of the epoch  4 the steps is:  295033
# 0.0  step  55034  of the epoch  4 the steps is:  295034
# 0.0  step  55035  of the epoch  4 the steps is:  295035
# 3.2624673988517756  step  55036  of the epoch  4 the steps is:  295036
# 1.7917887934829757  step  55037  of the epoch  4 the steps is:  295037
# 1.5858607523078527  step  55038  of the epoch  4 the steps is:  295038
# 0.0  step  55039  of the epoch  4 the steps is:  295039
# 0.0  step  55040  of the epoch  4 the steps is:  295040
# 0.0  step  55041  of the epoch  4 the steps is:  295041
# 0.0  step  55042  of the epoch  4 the steps is:  295042
# 0.0  step  55043  of the epoch  4 the steps is:  295043
# 0.13684963134833072  step  55044  of the epoch  4 the steps is:  295044
# 0.0  step  55045  of the epoch  4 the steps is:  295045
# 0.0  step  55046  of the epoch  4 the steps is:  295046
# 0.0  step  55047  of the epoch  4 the steps is:  295047
# 0.0  step  55048  of the epoch  4 the steps is:  295048
# 0.0  step  55049  of the epoch  4 the steps is:  295049
# 0.0  step  55050  of the epoch  4 the steps is:  295050
# 0.0  step  55051  of the epoch  4 the steps is:  295051
# 0.0  step  55052  of the epoch  4 the steps is:  295052
# 0.0  step  55053  of the epoch  4 the steps is:  295053
# 0.0  step  55054  of the epoch  4 the steps is:  295054
# 0.0  step  55055  of the epoch  4 the steps is:  295055
# 0.0  step  55056  of the epoch  4 the steps is:  295056
# 0.0  step  55057  of the epoch  4 the steps is:  295057
# 0.0  step  55058  of the epoch  4 the steps is:  295058
# 0.0  step  55059  of the epoch  4 the steps is:  295059
# 0.0  step  55060  of the epoch  4 the steps is:  295060
# 0.0  step  55061  of the epoch  4 the steps is:  295061
# 0.0  step  55062  of the epoch  4 the steps is:  295062
# 0.0  step  55063  of the epoch  4 the steps is:  295063
# 0.0  step  55064  of the epoch  4 the steps is:  295064
# 3.9439057078455892  step  55065  of the epoch  4 the steps is:  295065
# 0.0  step  55066  of the epoch  4 the steps is:  295066
# 0.0  step  55067  of the epoch  4 the steps is:  295067
# 0.0  step  55068  of the epoch  4 the steps is:  295068
# 0.09272619533675819  step  55069  of the epoch  4 the steps is:  295069
# 0.0  step  55070  of the epoch  4 the steps is:  295070
# 1.7729551413876852  step  55071  of the epoch  4 the steps is:  295071
# 0.0  step  55072  of the epoch  4 the steps is:  295072
# 0.0  step  55073  of the epoch  4 the steps is:  295073
# 0.0  step  55074  of the epoch  4 the steps is:  295074
# 0.7421403082172664  step  55075  of the epoch  4 the steps is:  295075
# 0.08967618687830825  step  55076  of the epoch  4 the steps is:  295076
# 0.0  step  55077  of the epoch  4 the steps is:  295077
# 0.2690952158891844  step  55078  of the epoch  4 the steps is:  295078
# 0.0  step  55079  of the epoch  4 the steps is:  295079
# 0.0  step  55080  of the epoch  4 the steps is:  295080
# 4.419405861373868  step  55081  of the epoch  4 the steps is:  295081
# 0.0  step  55082  of the epoch  4 the steps is:  295082
# 0.0  step  55083  of the epoch  4 the steps is:  295083
# 0.0  step  55084  of the epoch  4 the steps is:  295084
# 0.0  step  55085  of the epoch  4 the steps is:  295085
# 0.0  step  55086  of the epoch  4 the steps is:  295086
# 0.0  step  55087  of the epoch  4 the steps is:  295087
# 0.0  step  55088  of the epoch  4 the steps is:  295088
# 0.0  step  55089  of the epoch  4 the steps is:  295089
# 0.0  step  55090  of the epoch  4 the steps is:  295090
# 0.0  step  55091  of the epoch  4 the steps is:  295091
# 0.0  step  55092  of the epoch  4 the steps is:  295092
# 0.0  step  55093  of the epoch  4 the steps is:  295093
# 0.0  step  55094  of the epoch  4 the steps is:  295094
# 0.0  step  55095  of the epoch  4 the steps is:  295095
# 0.5018765406057195  step  55096  of the epoch  4 the steps is:  295096
# 0.0  step  55097  of the epoch  4 the steps is:  295097
# 0.7702889435116691  step  55098  of the epoch  4 the steps is:  295098
# 0.0  step  55099  of the epoch  4 the steps is:  295099
# 0.0  step  55100  of the epoch  4 the steps is:  295100
# 0.0  step  55101  of the epoch  4 the steps is:  295101
# 0.0  step  55102  of the epoch  4 the steps is:  295102
# 0.0  step  55103  of the epoch  4 the steps is:  295103
# 0.0  step  55104  of the epoch  4 the steps is:  295104
# 0.0  step  55105  of the epoch  4 the steps is:  295105
# 0.0  step  55106  of the epoch  4 the steps is:  295106
# 0.0  step  55107  of the epoch  4 the steps is:  295107
# 0.0  step  55108  of the epoch  4 the steps is:  295108
# 0.0  step  55109  of the epoch  4 the steps is:  295109
# 0.0  step  55110  of the epoch  4 the steps is:  295110
# 0.0  step  55111  of the epoch  4 the steps is:  295111
# 0.0  step  55112  of the epoch  4 the steps is:  295112
# 0.0  step  55113  of the epoch  4 the steps is:  295113
# 0.7510490062888002  step  55114  of the epoch  4 the steps is:  295114
# 0.0  step  55115  of the epoch  4 the steps is:  295115
# 0.0  step  55116  of the epoch  4 the steps is:  295116
# 0.0  step  55117  of the epoch  4 the steps is:  295117
# 0.7609165031938527  step  55118  of the epoch  4 the steps is:  295118
# 0.0  step  55119  of the epoch  4 the steps is:  295119
# 0.0  step  55120  of the epoch  4 the steps is:  295120
# 0.8938734137105397  step  55121  of the epoch  4 the steps is:  295121
# 0.0  step  55122  of the epoch  4 the steps is:  295122
# 0.0  step  55123  of the epoch  4 the steps is:  295123
# 0.0  step  55124  of the epoch  4 the steps is:  295124
# 1.0012480872260916  step  55125  of the epoch  4 the steps is:  295125
# 2.8625093140971725  step  55126  of the epoch  4 the steps is:  295126
# 0.0  step  55127  of the epoch  4 the steps is:  295127
# 0.1454464143454106  step  55128  of the epoch  4 the steps is:  295128
# 0.0  step  55129  of the epoch  4 the steps is:  295129
# 0.0  step  55130  of the epoch  4 the steps is:  295130
# 0.0  step  55131  of the epoch  4 the steps is:  295131
# 0.0  step  55132  of the epoch  4 the steps is:  295132
# 0.0  step  55133  of the epoch  4 the steps is:  295133
# 0.0  step  55134  of the epoch  4 the steps is:  295134
# 0.0  step  55135  of the epoch  4 the steps is:  295135
# 1.3716499782003275  step  55136  of the epoch  4 the steps is:  295136
# 0.0  step  55137  of the epoch  4 the steps is:  295137
# 0.0  step  55138  of the epoch  4 the steps is:  295138
# 0.0  step  55139  of the epoch  4 the steps is:  295139
# 0.0  step  55140  of the epoch  4 the steps is:  295140
# 0.0  step  55141  of the epoch  4 the steps is:  295141
# 0.0  step  55142  of the epoch  4 the steps is:  295142
# 0.0  step  55143  of the epoch  4 the steps is:  295143
# 0.4138282815940526  step  55144  of the epoch  4 the steps is:  295144
# 0.0  step  55145  of the epoch  4 the steps is:  295145
# 0.0  step  55146  of the epoch  4 the steps is:  295146
# 0.0  step  55147  of the epoch  4 the steps is:  295147
# 0.0  step  55148  of the epoch  4 the steps is:  295148
# 0.0  step  55149  of the epoch  4 the steps is:  295149
# 0.0  step  55150  of the epoch  4 the steps is:  295150
# 0.0  step  55151  of the epoch  4 the steps is:  295151
# 1.6131297178069604  step  55152  of the epoch  4 the steps is:  295152
# 0.0  step  55153  of the epoch  4 the steps is:  295153
# 0.0  step  55154  of the epoch  4 the steps is:  295154
# 0.6427924083220775  step  55155  of the epoch  4 the steps is:  295155
# 0.0  step  55156  of the epoch  4 the steps is:  295156
# 2.117636061045438  step  55157  of the epoch  4 the steps is:  295157
# 0.0  step  55158  of the epoch  4 the steps is:  295158
# 0.6720123260380895  step  55159  of the epoch  4 the steps is:  295159
# 0.0  step  55160  of the epoch  4 the steps is:  295160
# 0.0  step  55161  of the epoch  4 the steps is:  295161
# 0.0  step  55162  of the epoch  4 the steps is:  295162
# 0.0  step  55163  of the epoch  4 the steps is:  295163
# 1.2729433511249475  step  55164  of the epoch  4 the steps is:  295164
# 0.0  step  55165  of the epoch  4 the steps is:  295165
# 0.0  step  55166  of the epoch  4 the steps is:  295166
# 0.0  step  55167  of the epoch  4 the steps is:  295167
# 0.0  step  55168  of the epoch  4 the steps is:  295168
# 0.0  step  55169  of the epoch  4 the steps is:  295169
# 2.3437165336753427  step  55170  of the epoch  4 the steps is:  295170
# 0.0  step  55171  of the epoch  4 the steps is:  295171
# 0.0  step  55172  of the epoch  4 the steps is:  295172
# 0.0  step  55173  of the epoch  4 the steps is:  295173
# 0.0  step  55174  of the epoch  4 the steps is:  295174
# 0.0  step  55175  of the epoch  4 the steps is:  295175
# 0.0  step  55176  of the epoch  4 the steps is:  295176
# 0.0  step  55177  of the epoch  4 the steps is:  295177
# 0.0  step  55178  of the epoch  4 the steps is:  295178
# 0.0  step  55179  of the epoch  4 the steps is:  295179
# 0.0  step  55180  of the epoch  4 the steps is:  295180
# 0.0  step  55181  of the epoch  4 the steps is:  295181
# 0.0  step  55182  of the epoch  4 the steps is:  295182
# 0.0  step  55183  of the epoch  4 the steps is:  295183
# 1.533162489583055  step  55184  of the epoch  4 the steps is:  295184
# 0.0  step  55185  of the epoch  4 the steps is:  295185
# 0.02712480433244302  step  55186  of the epoch  4 the steps is:  295186
# 0.0  step  55187  of the epoch  4 the steps is:  295187
# 1.2829022499909994  step  55188  of the epoch  4 the steps is:  295188
# 0.0  step  55189  of the epoch  4 the steps is:  295189
# 1.3388960014075333  step  55190  of the epoch  4 the steps is:  295190
# 1.5185031823252562  step  55191  of the epoch  4 the steps is:  295191
# 0.0  step  55192  of the epoch  4 the steps is:  295192
# 0.0  step  55193  of the epoch  4 the steps is:  295193
# 0.0  step  55194  of the epoch  4 the steps is:  295194
# 0.16075683748791514  step  55195  of the epoch  4 the steps is:  295195
# 0.0  step  55196  of the epoch  4 the steps is:  295196
# 0.0  step  55197  of the epoch  4 the steps is:  295197
# 0.0  step  55198  of the epoch  4 the steps is:  295198
# 0.0  step  55199  of the epoch  4 the steps is:  295199
# 0.0  step  55200  of the epoch  4 the steps is:  295200
# 0.0  step  55201  of the epoch  4 the steps is:  295201
# 0.0  step  55202  of the epoch  4 the steps is:  295202
# 0.0  step  55203  of the epoch  4 the steps is:  295203
# 0.0  step  55204  of the epoch  4 the steps is:  295204
# 0.0  step  55205  of the epoch  4 the steps is:  295205
# 0.0  step  55206  of the epoch  4 the steps is:  295206
# 0.0  step  55207  of the epoch  4 the steps is:  295207
# 0.0  step  55208  of the epoch  4 the steps is:  295208
# 0.0  step  55209  of the epoch  4 the steps is:  295209
# 0.0  step  55210  of the epoch  4 the steps is:  295210
# 0.0  step  55211  of the epoch  4 the steps is:  295211
# 0.0  step  55212  of the epoch  4 the steps is:  295212
# 0.0  step  55213  of the epoch  4 the steps is:  295213
# 0.0  step  55214  of the epoch  4 the steps is:  295214
# 0.0  step  55215  of the epoch  4 the steps is:  295215
# 0.7711122369564727  step  55216  of the epoch  4 the steps is:  295216
# 0.0  step  55217  of the epoch  4 the steps is:  295217
# 0.0  step  55218  of the epoch  4 the steps is:  295218
# 0.0  step  55219  of the epoch  4 the steps is:  295219
# 0.0  step  55220  of the epoch  4 the steps is:  295220
# 0.0  step  55221  of the epoch  4 the steps is:  295221
# 0.0  step  55222  of the epoch  4 the steps is:  295222
# 0.0  step  55223  of the epoch  4 the steps is:  295223
# 0.6393022713131002  step  55224  of the epoch  4 the steps is:  295224
# 0.0  step  55225  of the epoch  4 the steps is:  295225
# 2.158733005322289  step  55226  of the epoch  4 the steps is:  295226
# 0.0  step  55227  of the epoch  4 the steps is:  295227
# 0.0  step  55228  of the epoch  4 the steps is:  295228
# 0.0  step  55229  of the epoch  4 the steps is:  295229
# 0.0388560083911722  step  55230  of the epoch  4 the steps is:  295230
# 0.0  step  55231  of the epoch  4 the steps is:  295231
# 0.0  step  55232  of the epoch  4 the steps is:  295232
# 0.0  step  55233  of the epoch  4 the steps is:  295233
# 0.0  step  55234  of the epoch  4 the steps is:  295234
# 0.0  step  55235  of the epoch  4 the steps is:  295235
# 4.023395934012401  step  55236  of the epoch  4 the steps is:  295236
# 4.2145442814563765  step  55237  of the epoch  4 the steps is:  295237
# 0.0  step  55238  of the epoch  4 the steps is:  295238
# 0.6786720001045579  step  55239  of the epoch  4 the steps is:  295239
# 0.33186320654068435  step  55240  of the epoch  4 the steps is:  295240
# 0.7274636662050229  step  55241  of the epoch  4 the steps is:  295241
# 0.6122676344280764  step  55242  of the epoch  4 the steps is:  295242
# 0.0  step  55243  of the epoch  4 the steps is:  295243
# 0.0  step  55244  of the epoch  4 the steps is:  295244
# 0.0  step  55245  of the epoch  4 the steps is:  295245
# 0.0  step  55246  of the epoch  4 the steps is:  295246
# 0.0  step  55247  of the epoch  4 the steps is:  295247
# 0.0  step  55248  of the epoch  4 the steps is:  295248
# 0.5460881998876013  step  55249  of the epoch  4 the steps is:  295249
# 0.0  step  55250  of the epoch  4 the steps is:  295250
# 0.0  step  55251  of the epoch  4 the steps is:  295251
# 0.0  step  55252  of the epoch  4 the steps is:  295252
# 0.0  step  55253  of the epoch  4 the steps is:  295253
# 0.0  step  55254  of the epoch  4 the steps is:  295254
# 0.0  step  55255  of the epoch  4 the steps is:  295255
# 0.0  step  55256  of the epoch  4 the steps is:  295256
# 0.0  step  55257  of the epoch  4 the steps is:  295257
# 2.11261320719953  step  55258  of the epoch  4 the steps is:  295258
# 0.0  step  55259  of the epoch  4 the steps is:  295259
# 0.0  step  55260  of the epoch  4 the steps is:  295260
# 3.733200333071437  step  55261  of the epoch  4 the steps is:  295261
# 0.0  step  55262  of the epoch  4 the steps is:  295262
# 0.0  step  55263  of the epoch  4 the steps is:  295263
# 0.0  step  55264  of the epoch  4 the steps is:  295264
# 0.0  step  55265  of the epoch  4 the steps is:  295265
# 0.0  step  55266  of the epoch  4 the steps is:  295266
# 0.1604626766914543  step  55267  of the epoch  4 the steps is:  295267
# 0.0  step  55268  of the epoch  4 the steps is:  295268
# 1.4505588657357178  step  55269  of the epoch  4 the steps is:  295269
# 0.0  step  55270  of the epoch  4 the steps is:  295270
# 0.0  step  55271  of the epoch  4 the steps is:  295271
# 0.0  step  55272  of the epoch  4 the steps is:  295272
# 0.0  step  55273  of the epoch  4 the steps is:  295273
# 0.4088697503621179  step  55274  of the epoch  4 the steps is:  295274
# 4.716614003981042  step  55275  of the epoch  4 the steps is:  295275
# 0.0  step  55276  of the epoch  4 the steps is:  295276
# 0.0  step  55277  of the epoch  4 the steps is:  295277
# 0.0  step  55278  of the epoch  4 the steps is:  295278
# 0.0  step  55279  of the epoch  4 the steps is:  295279
# 0.0  step  55280  of the epoch  4 the steps is:  295280
# 0.5184911198911264  step  55281  of the epoch  4 the steps is:  295281
# 0.0  step  55282  of the epoch  4 the steps is:  295282
# 0.0  step  55283  of the epoch  4 the steps is:  295283
# 0.609799845194325  step  55284  of the epoch  4 the steps is:  295284
# 0.0  step  55285  of the epoch  4 the steps is:  295285
# 0.0  step  55286  of the epoch  4 the steps is:  295286
# 0.0  step  55287  of the epoch  4 the steps is:  295287
# 0.0  step  55288  of the epoch  4 the steps is:  295288
# 0.0  step  55289  of the epoch  4 the steps is:  295289
# 0.0  step  55290  of the epoch  4 the steps is:  295290
# 0.0  step  55291  of the epoch  4 the steps is:  295291
# 0.0  step  55292  of the epoch  4 the steps is:  295292
# 0.0  step  55293  of the epoch  4 the steps is:  295293
# 0.38093304425932306  step  55294  of the epoch  4 the steps is:  295294
# 0.0  step  55295  of the epoch  4 the steps is:  295295
# 0.0  step  55296  of the epoch  4 the steps is:  295296
# 0.0  step  55297  of the epoch  4 the steps is:  295297
# 0.7401995543497097  step  55298  of the epoch  4 the steps is:  295298
# 0.0  step  55299  of the epoch  4 the steps is:  295299
# 0.0  step  55300  of the epoch  4 the steps is:  295300
# 1.814400829849732  step  55301  of the epoch  4 the steps is:  295301
# 0.0  step  55302  of the epoch  4 the steps is:  295302
# 0.0  step  55303  of the epoch  4 the steps is:  295303
# 0.0  step  55304  of the epoch  4 the steps is:  295304
# 0.0  step  55305  of the epoch  4 the steps is:  295305
# 0.0  step  55306  of the epoch  4 the steps is:  295306
# 0.5714149462093729  step  55307  of the epoch  4 the steps is:  295307
# 0.0  step  55308  of the epoch  4 the steps is:  295308
# 2.3074383410365567  step  55309  of the epoch  4 the steps is:  295309
# 0.0  step  55310  of the epoch  4 the steps is:  295310
# 0.0  step  55311  of the epoch  4 the steps is:  295311
# 0.7848103641152493  step  55312  of the epoch  4 the steps is:  295312
# 0.0  step  55313  of the epoch  4 the steps is:  295313
# 0.0  step  55314  of the epoch  4 the steps is:  295314
# 0.0  step  55315  of the epoch  4 the steps is:  295315
# 0.0  step  55316  of the epoch  4 the steps is:  295316
# 0.0  step  55317  of the epoch  4 the steps is:  295317
# 0.0  step  55318  of the epoch  4 the steps is:  295318
# 0.0  step  55319  of the epoch  4 the steps is:  295319
# 0.0  step  55320  of the epoch  4 the steps is:  295320
# 0.0  step  55321  of the epoch  4 the steps is:  295321
# 0.0  step  55322  of the epoch  4 the steps is:  295322
# 0.565581375178144  step  55323  of the epoch  4 the steps is:  295323
# 0.0  step  55324  of the epoch  4 the steps is:  295324
# 2.5375939486510664  step  55325  of the epoch  4 the steps is:  295325
# 0.0  step  55326  of the epoch  4 the steps is:  295326
# 0.0  step  55327  of the epoch  4 the steps is:  295327
# 0.0  step  55328  of the epoch  4 the steps is:  295328
# 0.0  step  55329  of the epoch  4 the steps is:  295329
# 0.0  step  55330  of the epoch  4 the steps is:  295330
# 0.0  step  55331  of the epoch  4 the steps is:  295331
# 0.6605316445265825  step  55332  of the epoch  4 the steps is:  295332
# 0.9880491761301098  step  55333  of the epoch  4 the steps is:  295333
# 0.19870326314770326  step  55334  of the epoch  4 the steps is:  295334
# 0.0  step  55335  of the epoch  4 the steps is:  295335
# 1.1168091557984878  step  55336  of the epoch  4 the steps is:  295336
# 0.0  step  55337  of the epoch  4 the steps is:  295337
# 0.0  step  55338  of the epoch  4 the steps is:  295338
# 0.0  step  55339  of the epoch  4 the steps is:  295339
# 0.0  step  55340  of the epoch  4 the steps is:  295340
# 0.0  step  55341  of the epoch  4 the steps is:  295341
# 0.0  step  55342  of the epoch  4 the steps is:  295342
# 0.0  step  55343  of the epoch  4 the steps is:  295343
# 0.0  step  55344  of the epoch  4 the steps is:  295344
# 0.0  step  55345  of the epoch  4 the steps is:  295345
# 0.0  step  55346  of the epoch  4 the steps is:  295346
# 3.995153677409954  step  55347  of the epoch  4 the steps is:  295347
# 0.0  step  55348  of the epoch  4 the steps is:  295348
# 0.0  step  55349  of the epoch  4 the steps is:  295349
# 0.0  step  55350  of the epoch  4 the steps is:  295350
# 1.5802328034130477  step  55351  of the epoch  4 the steps is:  295351
# 1.750847972958793  step  55352  of the epoch  4 the steps is:  295352
# 0.0  step  55353  of the epoch  4 the steps is:  295353
# 0.0  step  55354  of the epoch  4 the steps is:  295354
# 0.0  step  55355  of the epoch  4 the steps is:  295355
# 0.0  step  55356  of the epoch  4 the steps is:  295356
# 0.0  step  55357  of the epoch  4 the steps is:  295357
# 0.0  step  55358  of the epoch  4 the steps is:  295358
# 4.1519252914225735  step  55359  of the epoch  4 the steps is:  295359
# 0.0  step  55360  of the epoch  4 the steps is:  295360
# 0.0  step  55361  of the epoch  4 the steps is:  295361
# 2.797890486669837  step  55362  of the epoch  4 the steps is:  295362
# 0.0  step  55363  of the epoch  4 the steps is:  295363
# 0.0  step  55364  of the epoch  4 the steps is:  295364
# 0.0  step  55365  of the epoch  4 the steps is:  295365
# 0.0  step  55366  of the epoch  4 the steps is:  295366
# 0.0  step  55367  of the epoch  4 the steps is:  295367
# 0.0  step  55368  of the epoch  4 the steps is:  295368
# 0.0  step  55369  of the epoch  4 the steps is:  295369
# 0.0  step  55370  of the epoch  4 the steps is:  295370
# 1.3516047946288192  step  55371  of the epoch  4 the steps is:  295371
# 0.8146797553262664  step  55372  of the epoch  4 the steps is:  295372
# 0.0  step  55373  of the epoch  4 the steps is:  295373
# 0.0  step  55374  of the epoch  4 the steps is:  295374
# 0.0  step  55375  of the epoch  4 the steps is:  295375
# 0.0  step  55376  of the epoch  4 the steps is:  295376
# 0.0  step  55377  of the epoch  4 the steps is:  295377
# 0.0  step  55378  of the epoch  4 the steps is:  295378
# 0.0  step  55379  of the epoch  4 the steps is:  295379
# 0.22362807744466995  step  55380  of the epoch  4 the steps is:  295380
# 0.0  step  55381  of the epoch  4 the steps is:  295381
# 0.0  step  55382  of the epoch  4 the steps is:  295382
# 0.0  step  55383  of the epoch  4 the steps is:  295383
# 0.0  step  55384  of the epoch  4 the steps is:  295384
# 0.0  step  55385  of the epoch  4 the steps is:  295385
# 0.0  step  55386  of the epoch  4 the steps is:  295386
# 0.0  step  55387  of the epoch  4 the steps is:  295387
# 0.0  step  55388  of the epoch  4 the steps is:  295388
# 0.0  step  55389  of the epoch  4 the steps is:  295389
# 0.0  step  55390  of the epoch  4 the steps is:  295390
# 0.0  step  55391  of the epoch  4 the steps is:  295391
# 0.4347227283891466  step  55392  of the epoch  4 the steps is:  295392
# 0.0  step  55393  of the epoch  4 the steps is:  295393
# 0.0  step  55394  of the epoch  4 the steps is:  295394
# 0.0  step  55395  of the epoch  4 the steps is:  295395
# 0.0  step  55396  of the epoch  4 the steps is:  295396
# 0.0  step  55397  of the epoch  4 the steps is:  295397
# 0.0  step  55398  of the epoch  4 the steps is:  295398
# 1.491269895376817  step  55399  of the epoch  4 the steps is:  295399
# 0.0  step  55400  of the epoch  4 the steps is:  295400
# 0.0  step  55401  of the epoch  4 the steps is:  295401
# 1.1183295201744499  step  55402  of the epoch  4 the steps is:  295402
# 0.0  step  55403  of the epoch  4 the steps is:  295403
# 0.0  step  55404  of the epoch  4 the steps is:  295404
# 0.11347363322770487  step  55405  of the epoch  4 the steps is:  295405
# 0.0  step  55406  of the epoch  4 the steps is:  295406
# 0.0  step  55407  of the epoch  4 the steps is:  295407
# 0.0  step  55408  of the epoch  4 the steps is:  295408
# 0.0  step  55409  of the epoch  4 the steps is:  295409
# 0.0  step  55410  of the epoch  4 the steps is:  295410
# 0.0  step  55411  of the epoch  4 the steps is:  295411
# 1.1355196604046638  step  55412  of the epoch  4 the steps is:  295412
# 0.0  step  55413  of the epoch  4 the steps is:  295413
# 0.0  step  55414  of the epoch  4 the steps is:  295414
# 0.0  step  55415  of the epoch  4 the steps is:  295415
# 0.0  step  55416  of the epoch  4 the steps is:  295416
# 0.0  step  55417  of the epoch  4 the steps is:  295417
# 0.0  step  55418  of the epoch  4 the steps is:  295418
# 0.0  step  55419  of the epoch  4 the steps is:  295419
# 0.5959081636732968  step  55420  of the epoch  4 the steps is:  295420
# 0.12754901162385845  step  55421  of the epoch  4 the steps is:  295421
# 0.0  step  55422  of the epoch  4 the steps is:  295422
# 0.0  step  55423  of the epoch  4 the steps is:  295423
# 0.0  step  55424  of the epoch  4 the steps is:  295424
# 0.12557718094379222  step  55425  of the epoch  4 the steps is:  295425
# 0.0  step  55426  of the epoch  4 the steps is:  295426
# 0.0  step  55427  of the epoch  4 the steps is:  295427
# 0.0  step  55428  of the epoch  4 the steps is:  295428
# 5.023286351716377  step  55429  of the epoch  4 the steps is:  295429
# 0.0  step  55430  of the epoch  4 the steps is:  295430
# 0.0  step  55431  of the epoch  4 the steps is:  295431
# 0.0  step  55432  of the epoch  4 the steps is:  295432
# 0.0  step  55433  of the epoch  4 the steps is:  295433
# 0.0  step  55434  of the epoch  4 the steps is:  295434
# 0.0  step  55435  of the epoch  4 the steps is:  295435
# 0.0  step  55436  of the epoch  4 the steps is:  295436
# 0.0  step  55437  of the epoch  4 the steps is:  295437
# 2.334994119949547  step  55438  of the epoch  4 the steps is:  295438
# 0.0  step  55439  of the epoch  4 the steps is:  295439
# 0.0  step  55440  of the epoch  4 the steps is:  295440
# 0.0  step  55441  of the epoch  4 the steps is:  295441
# 0.0  step  55442  of the epoch  4 the steps is:  295442
# 0.0  step  55443  of the epoch  4 the steps is:  295443
# 0.0  step  55444  of the epoch  4 the steps is:  295444
# 0.0  step  55445  of the epoch  4 the steps is:  295445
# 0.0  step  55446  of the epoch  4 the steps is:  295446
# 0.0  step  55447  of the epoch  4 the steps is:  295447
# 0.05922938592409199  step  55448  of the epoch  4 the steps is:  295448
# 0.0  step  55449  of the epoch  4 the steps is:  295449
# 0.0  step  55450  of the epoch  4 the steps is:  295450
# 0.0  step  55451  of the epoch  4 the steps is:  295451
# 0.0  step  55452  of the epoch  4 the steps is:  295452
# 0.0  step  55453  of the epoch  4 the steps is:  295453
# 0.0  step  55454  of the epoch  4 the steps is:  295454
# 0.0  step  55455  of the epoch  4 the steps is:  295455
# 1.1983072446994836  step  55456  of the epoch  4 the steps is:  295456
# 0.0  step  55457  of the epoch  4 the steps is:  295457
# 0.0  step  55458  of the epoch  4 the steps is:  295458
# 0.0  step  55459  of the epoch  4 the steps is:  295459
# 0.0  step  55460  of the epoch  4 the steps is:  295460
# 0.0  step  55461  of the epoch  4 the steps is:  295461
# 0.3677130387838994  step  55462  of the epoch  4 the steps is:  295462
# 0.0  step  55463  of the epoch  4 the steps is:  295463
# 2.4997288898112524  step  55464  of the epoch  4 the steps is:  295464
# 0.0  step  55465  of the epoch  4 the steps is:  295465
# 0.0  step  55466  of the epoch  4 the steps is:  295466
# 3.1986884551661  step  55467  of the epoch  4 the steps is:  295467
# 0.011233579201484378  step  55468  of the epoch  4 the steps is:  295468
# 2.1507678447220764  step  55469  of the epoch  4 the steps is:  295469
# 0.0947084809573644  step  55470  of the epoch  4 the steps is:  295470
# 0.0  step  55471  of the epoch  4 the steps is:  295471
# 0.0  step  55472  of the epoch  4 the steps is:  295472
# 0.0  step  55473  of the epoch  4 the steps is:  295473
# 0.9393238840798008  step  55474  of the epoch  4 the steps is:  295474
# 0.0  step  55475  of the epoch  4 the steps is:  295475
# 0.0  step  55476  of the epoch  4 the steps is:  295476
# 0.0  step  55477  of the epoch  4 the steps is:  295477
# 0.0  step  55478  of the epoch  4 the steps is:  295478
# 0.9674467315786046  step  55479  of the epoch  4 the steps is:  295479
# 0.0  step  55480  of the epoch  4 the steps is:  295480
# 0.0  step  55481  of the epoch  4 the steps is:  295481
# 0.0  step  55482  of the epoch  4 the steps is:  295482
# 0.5440585461469185  step  55483  of the epoch  4 the steps is:  295483
# 0.0  step  55484  of the epoch  4 the steps is:  295484
# 0.0  step  55485  of the epoch  4 the steps is:  295485
# 0.0  step  55486  of the epoch  4 the steps is:  295486
# 0.0  step  55487  of the epoch  4 the steps is:  295487
# 0.0  step  55488  of the epoch  4 the steps is:  295488
# 0.0  step  55489  of the epoch  4 the steps is:  295489
# 0.0  step  55490  of the epoch  4 the steps is:  295490
# 0.0  step  55491  of the epoch  4 the steps is:  295491
# 0.4989221997012203  step  55492  of the epoch  4 the steps is:  295492
# 1.9022457009041638  step  55493  of the epoch  4 the steps is:  295493
# 2.4901929899375466  step  55494  of the epoch  4 the steps is:  295494
# 0.0  step  55495  of the epoch  4 the steps is:  295495
# 0.0  step  55496  of the epoch  4 the steps is:  295496
# 0.0  step  55497  of the epoch  4 the steps is:  295497
# 0.0  step  55498  of the epoch  4 the steps is:  295498
# 0.0  step  55499  of the epoch  4 the steps is:  295499
# 0.0  step  55500  of the epoch  4 the steps is:  295500
# 0.0  step  55501  of the epoch  4 the steps is:  295501
# 0.0  step  55502  of the epoch  4 the steps is:  295502
# 0.0  step  55503  of the epoch  4 the steps is:  295503
# 0.0  step  55504  of the epoch  4 the steps is:  295504
# 0.0  step  55505  of the epoch  4 the steps is:  295505
# 0.0  step  55506  of the epoch  4 the steps is:  295506
# 0.4480564054260059  step  55507  of the epoch  4 the steps is:  295507
# 1.4627570643639656  step  55508  of the epoch  4 the steps is:  295508
# 0.0  step  55509  of the epoch  4 the steps is:  295509
# 0.0  step  55510  of the epoch  4 the steps is:  295510
# 0.0  step  55511  of the epoch  4 the steps is:  295511
# 0.0  step  55512  of the epoch  4 the steps is:  295512
# 0.0  step  55513  of the epoch  4 the steps is:  295513
# 0.0  step  55514  of the epoch  4 the steps is:  295514
# 0.0  step  55515  of the epoch  4 the steps is:  295515
# 0.0  step  55516  of the epoch  4 the steps is:  295516
# 0.0  step  55517  of the epoch  4 the steps is:  295517
# 0.0  step  55518  of the epoch  4 the steps is:  295518
# 0.0  step  55519  of the epoch  4 the steps is:  295519
# 0.0  step  55520  of the epoch  4 the steps is:  295520
# 0.0  step  55521  of the epoch  4 the steps is:  295521
# 0.0  step  55522  of the epoch  4 the steps is:  295522
# 0.0  step  55523  of the epoch  4 the steps is:  295523
# 0.0  step  55524  of the epoch  4 the steps is:  295524
# 0.0  step  55525  of the epoch  4 the steps is:  295525
# 0.0  step  55526  of the epoch  4 the steps is:  295526
# 0.0  step  55527  of the epoch  4 the steps is:  295527
# 0.9272040855457648  step  55528  of the epoch  4 the steps is:  295528
# 0.0  step  55529  of the epoch  4 the steps is:  295529
# 0.0  step  55530  of the epoch  4 the steps is:  295530
# 0.0  step  55531  of the epoch  4 the steps is:  295531
# 0.0  step  55532  of the epoch  4 the steps is:  295532
# 0.0  step  55533  of the epoch  4 the steps is:  295533
# 3.1774042255689894  step  55534  of the epoch  4 the steps is:  295534
# 0.0  step  55535  of the epoch  4 the steps is:  295535
# 5.261078676162468  step  55536  of the epoch  4 the steps is:  295536
# 0.0  step  55537  of the epoch  4 the steps is:  295537
# 0.0  step  55538  of the epoch  4 the steps is:  295538
# 0.0  step  55539  of the epoch  4 the steps is:  295539
# 1.2185825002289596  step  55540  of the epoch  4 the steps is:  295540
# 3.9181511997447114  step  55541  of the epoch  4 the steps is:  295541
# 0.0  step  55542  of the epoch  4 the steps is:  295542
# 1.161646360249227  step  55543  of the epoch  4 the steps is:  295543
# 0.0  step  55544  of the epoch  4 the steps is:  295544
# 0.0  step  55545  of the epoch  4 the steps is:  295545
# 0.0  step  55546  of the epoch  4 the steps is:  295546
# 0.0  step  55547  of the epoch  4 the steps is:  295547
# 0.0  step  55548  of the epoch  4 the steps is:  295548
# 0.0  step  55549  of the epoch  4 the steps is:  295549
# 0.0  step  55550  of the epoch  4 the steps is:  295550
# 0.0  step  55551  of the epoch  4 the steps is:  295551
# 0.0  step  55552  of the epoch  4 the steps is:  295552
# 0.0  step  55553  of the epoch  4 the steps is:  295553
# 0.03437312300734918  step  55554  of the epoch  4 the steps is:  295554
# 0.0  step  55555  of the epoch  4 the steps is:  295555
# 0.0  step  55556  of the epoch  4 the steps is:  295556
# 1.0257612052562037  step  55557  of the epoch  4 the steps is:  295557
# 0.0  step  55558  of the epoch  4 the steps is:  295558
# 3.162226708061424  step  55559  of the epoch  4 the steps is:  295559
# 0.44537978119226507  step  55560  of the epoch  4 the steps is:  295560
# 0.0  step  55561  of the epoch  4 the steps is:  295561
# 0.0  step  55562  of the epoch  4 the steps is:  295562
# 0.0  step  55563  of the epoch  4 the steps is:  295563
# 0.0  step  55564  of the epoch  4 the steps is:  295564
# 0.0  step  55565  of the epoch  4 the steps is:  295565
# 0.0  step  55566  of the epoch  4 the steps is:  295566
# 0.8258210946844109  step  55567  of the epoch  4 the steps is:  295567
# 0.0  step  55568  of the epoch  4 the steps is:  295568
# 8.605623861554555  step  55569  of the epoch  4 the steps is:  295569
# 0.0  step  55570  of the epoch  4 the steps is:  295570
# 0.0  step  55571  of the epoch  4 the steps is:  295571
# 0.7514530313619403  step  55572  of the epoch  4 the steps is:  295572
# 0.0  step  55573  of the epoch  4 the steps is:  295573
# 0.0  step  55574  of the epoch  4 the steps is:  295574
# 0.4825825511272903  step  55575  of the epoch  4 the steps is:  295575
# 0.0  step  55576  of the epoch  4 the steps is:  295576
# 0.0  step  55577  of the epoch  4 the steps is:  295577
# 0.5006542529381832  step  55578  of the epoch  4 the steps is:  295578
# 1.261538640710528  step  55579  of the epoch  4 the steps is:  295579
# 0.0  step  55580  of the epoch  4 the steps is:  295580
# 0.0  step  55581  of the epoch  4 the steps is:  295581
# 0.0  step  55582  of the epoch  4 the steps is:  295582
# 0.0  step  55583  of the epoch  4 the steps is:  295583
# 3.0918317173989394  step  55584  of the epoch  4 the steps is:  295584
# 0.0  step  55585  of the epoch  4 the steps is:  295585
# 0.0  step  55586  of the epoch  4 the steps is:  295586
# 0.11737832094201028  step  55587  of the epoch  4 the steps is:  295587
# 0.3022624829677638  step  55588  of the epoch  4 the steps is:  295588
# 0.0  step  55589  of the epoch  4 the steps is:  295589
# 0.0  step  55590  of the epoch  4 the steps is:  295590
# 0.07833751387349297  step  55591  of the epoch  4 the steps is:  295591
# 0.0  step  55592  of the epoch  4 the steps is:  295592
# 0.0  step  55593  of the epoch  4 the steps is:  295593
# 0.0  step  55594  of the epoch  4 the steps is:  295594
# 0.33074243190840047  step  55595  of the epoch  4 the steps is:  295595
# 0.0  step  55596  of the epoch  4 the steps is:  295596
# 0.0  step  55597  of the epoch  4 the steps is:  295597
# 0.0  step  55598  of the epoch  4 the steps is:  295598
# 0.0  step  55599  of the epoch  4 the steps is:  295599
# 0.0  step  55600  of the epoch  4 the steps is:  295600
# 0.0  step  55601  of the epoch  4 the steps is:  295601
# 0.0  step  55602  of the epoch  4 the steps is:  295602
# 0.0  step  55603  of the epoch  4 the steps is:  295603
# 0.0  step  55604  of the epoch  4 the steps is:  295604
# 0.0  step  55605  of the epoch  4 the steps is:  295605
# 0.0  step  55606  of the epoch  4 the steps is:  295606
# 0.0  step  55607  of the epoch  4 the steps is:  295607
# 0.0  step  55608  of the epoch  4 the steps is:  295608
# 0.0  step  55609  of the epoch  4 the steps is:  295609
# 0.0  step  55610  of the epoch  4 the steps is:  295610
# 0.0  step  55611  of the epoch  4 the steps is:  295611
# 0.0  step  55612  of the epoch  4 the steps is:  295612
# 0.0  step  55613  of the epoch  4 the steps is:  295613
# 0.0  step  55614  of the epoch  4 the steps is:  295614
# 0.0  step  55615  of the epoch  4 the steps is:  295615
# 0.0  step  55616  of the epoch  4 the steps is:  295616
# 0.0  step  55617  of the epoch  4 the steps is:  295617
# 0.0  step  55618  of the epoch  4 the steps is:  295618
# 0.0  step  55619  of the epoch  4 the steps is:  295619
# 1.2175920125970352  step  55620  of the epoch  4 the steps is:  295620
# 0.0  step  55621  of the epoch  4 the steps is:  295621
# 0.0  step  55622  of the epoch  4 the steps is:  295622
# 5.477196006280426  step  55623  of the epoch  4 the steps is:  295623
# 0.0  step  55624  of the epoch  4 the steps is:  295624
# 0.0  step  55625  of the epoch  4 the steps is:  295625
# 0.0  step  55626  of the epoch  4 the steps is:  295626
# 0.0  step  55627  of the epoch  4 the steps is:  295627
# 0.0  step  55628  of the epoch  4 the steps is:  295628
# 0.0  step  55629  of the epoch  4 the steps is:  295629
# 0.21727216950643502  step  55630  of the epoch  4 the steps is:  295630
# 0.0  step  55631  of the epoch  4 the steps is:  295631
# 0.0  step  55632  of the epoch  4 the steps is:  295632
# 0.0  step  55633  of the epoch  4 the steps is:  295633
# 0.0  step  55634  of the epoch  4 the steps is:  295634
# 0.0  step  55635  of the epoch  4 the steps is:  295635
# 3.1452881758642333  step  55636  of the epoch  4 the steps is:  295636
# 0.0  step  55637  of the epoch  4 the steps is:  295637
# 0.0  step  55638  of the epoch  4 the steps is:  295638
# 0.0  step  55639  of the epoch  4 the steps is:  295639
# 0.5391349281094788  step  55640  of the epoch  4 the steps is:  295640
# 1.4818789166512651  step  55641  of the epoch  4 the steps is:  295641
# 3.2049963771912147  step  55642  of the epoch  4 the steps is:  295642
# 0.0  step  55643  of the epoch  4 the steps is:  295643
# 0.0  step  55644  of the epoch  4 the steps is:  295644
# 0.8131223055354413  step  55645  of the epoch  4 the steps is:  295645
# 0.0  step  55646  of the epoch  4 the steps is:  295646
# 0.0  step  55647  of the epoch  4 the steps is:  295647
# 0.0  step  55648  of the epoch  4 the steps is:  295648
# 1.1531274426616935  step  55649  of the epoch  4 the steps is:  295649
# 0.9508027971533419  step  55650  of the epoch  4 the steps is:  295650
# 0.0  step  55651  of the epoch  4 the steps is:  295651
# 0.0  step  55652  of the epoch  4 the steps is:  295652
# 0.0  step  55653  of the epoch  4 the steps is:  295653
# 0.0  step  55654  of the epoch  4 the steps is:  295654
# 8.362083253232587  step  55655  of the epoch  4 the steps is:  295655
# 0.9985276268281043  step  55656  of the epoch  4 the steps is:  295656
# 0.0  step  55657  of the epoch  4 the steps is:  295657
# 0.0  step  55658  of the epoch  4 the steps is:  295658
# 2.892212887434158  step  55659  of the epoch  4 the steps is:  295659
# 0.0  step  55660  of the epoch  4 the steps is:  295660
# 0.0  step  55661  of the epoch  4 the steps is:  295661
# 0.0  step  55662  of the epoch  4 the steps is:  295662
# 0.0  step  55663  of the epoch  4 the steps is:  295663
# 0.0  step  55664  of the epoch  4 the steps is:  295664
# 0.0  step  55665  of the epoch  4 the steps is:  295665
# 0.725040172006004  step  55666  of the epoch  4 the steps is:  295666
# 0.1081306943817042  step  55667  of the epoch  4 the steps is:  295667
# 0.0  step  55668  of the epoch  4 the steps is:  295668
# 0.0  step  55669  of the epoch  4 the steps is:  295669
# 0.0  step  55670  of the epoch  4 the steps is:  295670
# 0.0  step  55671  of the epoch  4 the steps is:  295671
# 0.0  step  55672  of the epoch  4 the steps is:  295672
# 0.0  step  55673  of the epoch  4 the steps is:  295673
# 0.0  step  55674  of the epoch  4 the steps is:  295674
# 0.0  step  55675  of the epoch  4 the steps is:  295675
# 0.0  step  55676  of the epoch  4 the steps is:  295676
# 0.0  step  55677  of the epoch  4 the steps is:  295677
# 0.0  step  55678  of the epoch  4 the steps is:  295678
# 0.3707999483677815  step  55679  of the epoch  4 the steps is:  295679
# 0.0  step  55680  of the epoch  4 the steps is:  295680
# 0.0  step  55681  of the epoch  4 the steps is:  295681
# 2.6484047187452724  step  55682  of the epoch  4 the steps is:  295682
# 0.0  step  55683  of the epoch  4 the steps is:  295683
# 0.0  step  55684  of the epoch  4 the steps is:  295684
# 0.0  step  55685  of the epoch  4 the steps is:  295685
# 0.0  step  55686  of the epoch  4 the steps is:  295686
# 0.487726337551579  step  55687  of the epoch  4 the steps is:  295687
# 0.0  step  55688  of the epoch  4 the steps is:  295688
# 0.0  step  55689  of the epoch  4 the steps is:  295689
# 1.3621791563893986  step  55690  of the epoch  4 the steps is:  295690
# 0.0  step  55691  of the epoch  4 the steps is:  295691
# 0.0  step  55692  of the epoch  4 the steps is:  295692
# 0.0  step  55693  of the epoch  4 the steps is:  295693
# 2.740533464707589  step  55694  of the epoch  4 the steps is:  295694
# 0.0  step  55695  of the epoch  4 the steps is:  295695
# 0.0  step  55696  of the epoch  4 the steps is:  295696
# 0.7617208336577379  step  55697  of the epoch  4 the steps is:  295697
# 0.0  step  55698  of the epoch  4 the steps is:  295698
# 0.0  step  55699  of the epoch  4 the steps is:  295699
# 0.0  step  55700  of the epoch  4 the steps is:  295700
# 0.0  step  55701  of the epoch  4 the steps is:  295701
# 0.17034516887051687  step  55702  of the epoch  4 the steps is:  295702
# 1.3480445441150337  step  55703  of the epoch  4 the steps is:  295703
# 0.0  step  55704  of the epoch  4 the steps is:  295704
# 1.915786572367892  step  55705  of the epoch  4 the steps is:  295705
# 3.9599258293129793  step  55706  of the epoch  4 the steps is:  295706
# 0.0  step  55707  of the epoch  4 the steps is:  295707
# 0.0  step  55708  of the epoch  4 the steps is:  295708
# 0.0  step  55709  of the epoch  4 the steps is:  295709
# 0.0  step  55710  of the epoch  4 the steps is:  295710
# 0.23252617458757108  step  55711  of the epoch  4 the steps is:  295711
# 0.0  step  55712  of the epoch  4 the steps is:  295712
# 0.0  step  55713  of the epoch  4 the steps is:  295713
# 1.0163773040402413  step  55714  of the epoch  4 the steps is:  295714
# 0.0  step  55715  of the epoch  4 the steps is:  295715
# 0.0  step  55716  of the epoch  4 the steps is:  295716
# 0.0  step  55717  of the epoch  4 the steps is:  295717
# 0.145571960398156  step  55718  of the epoch  4 the steps is:  295718
# 0.5799356274290264  step  55719  of the epoch  4 the steps is:  295719
# 0.0  step  55720  of the epoch  4 the steps is:  295720
# 0.0  step  55721  of the epoch  4 the steps is:  295721
# 0.0  step  55722  of the epoch  4 the steps is:  295722
# 0.0  step  55723  of the epoch  4 the steps is:  295723
# 0.0  step  55724  of the epoch  4 the steps is:  295724
# 0.0  step  55725  of the epoch  4 the steps is:  295725
# 0.0  step  55726  of the epoch  4 the steps is:  295726
# 2.612125247173651  step  55727  of the epoch  4 the steps is:  295727
# 0.0  step  55728  of the epoch  4 the steps is:  295728
# 1.3022898352159151  step  55729  of the epoch  4 the steps is:  295729
# 0.0  step  55730  of the epoch  4 the steps is:  295730
# 0.44205255597104287  step  55731  of the epoch  4 the steps is:  295731
# 0.0  step  55732  of the epoch  4 the steps is:  295732
# 0.0  step  55733  of the epoch  4 the steps is:  295733
# 0.0  step  55734  of the epoch  4 the steps is:  295734
# 0.0  step  55735  of the epoch  4 the steps is:  295735
# 0.0  step  55736  of the epoch  4 the steps is:  295736
# 0.0  step  55737  of the epoch  4 the steps is:  295737
# 0.009671098406679235  step  55738  of the epoch  4 the steps is:  295738
# 0.0  step  55739  of the epoch  4 the steps is:  295739
# 0.09197280930200158  step  55740  of the epoch  4 the steps is:  295740
# 0.0  step  55741  of the epoch  4 the steps is:  295741
# 0.0  step  55742  of the epoch  4 the steps is:  295742
# 2.6173963044025097  step  55743  of the epoch  4 the steps is:  295743
# 4.926337635174129  step  55744  of the epoch  4 the steps is:  295744
# 0.0  step  55745  of the epoch  4 the steps is:  295745
# 0.0  step  55746  of the epoch  4 the steps is:  295746
# 0.0  step  55747  of the epoch  4 the steps is:  295747
# 0.0  step  55748  of the epoch  4 the steps is:  295748
# 0.0988387397981656  step  55749  of the epoch  4 the steps is:  295749
# 0.0  step  55750  of the epoch  4 the steps is:  295750
# 0.0  step  55751  of the epoch  4 the steps is:  295751
# 0.0  step  55752  of the epoch  4 the steps is:  295752
# 0.0  step  55753  of the epoch  4 the steps is:  295753
# 0.0  step  55754  of the epoch  4 the steps is:  295754
# 0.7421002579965856  step  55755  of the epoch  4 the steps is:  295755
# 0.0  step  55756  of the epoch  4 the steps is:  295756
# 0.0  step  55757  of the epoch  4 the steps is:  295757
# 4.090338232356115  step  55758  of the epoch  4 the steps is:  295758
# 0.0  step  55759  of the epoch  4 the steps is:  295759
# 0.0  step  55760  of the epoch  4 the steps is:  295760
# 0.0  step  55761  of the epoch  4 the steps is:  295761
# 1.491002682132907  step  55762  of the epoch  4 the steps is:  295762
# 0.0  step  55763  of the epoch  4 the steps is:  295763
# 0.0  step  55764  of the epoch  4 the steps is:  295764
# 0.21526017340438708  step  55765  of the epoch  4 the steps is:  295765
# 0.7201588212202976  step  55766  of the epoch  4 the steps is:  295766
# 0.0  step  55767  of the epoch  4 the steps is:  295767
# 0.1153911858383938  step  55768  of the epoch  4 the steps is:  295768
# 0.0  step  55769  of the epoch  4 the steps is:  295769
# 0.0  step  55770  of the epoch  4 the steps is:  295770
# 0.0  step  55771  of the epoch  4 the steps is:  295771
# 0.0  step  55772  of the epoch  4 the steps is:  295772
# 0.0  step  55773  of the epoch  4 the steps is:  295773
# 0.0  step  55774  of the epoch  4 the steps is:  295774
# 0.0  step  55775  of the epoch  4 the steps is:  295775
# 1.065888553227154  step  55776  of the epoch  4 the steps is:  295776
# 0.0  step  55777  of the epoch  4 the steps is:  295777
# 0.0  step  55778  of the epoch  4 the steps is:  295778
# 0.0  step  55779  of the epoch  4 the steps is:  295779
# 0.0  step  55780  of the epoch  4 the steps is:  295780
# 0.0  step  55781  of the epoch  4 the steps is:  295781
# 0.0  step  55782  of the epoch  4 the steps is:  295782
# 0.0  step  55783  of the epoch  4 the steps is:  295783
# 1.3282835013636047  step  55784  of the epoch  4 the steps is:  295784
# 0.0  step  55785  of the epoch  4 the steps is:  295785
# 0.0  step  55786  of the epoch  4 the steps is:  295786
# 0.0  step  55787  of the epoch  4 the steps is:  295787
# 0.0  step  55788  of the epoch  4 the steps is:  295788
# 0.0  step  55789  of the epoch  4 the steps is:  295789
# 0.0  step  55790  of the epoch  4 the steps is:  295790
# 0.0  step  55791  of the epoch  4 the steps is:  295791
# 0.0  step  55792  of the epoch  4 the steps is:  295792
# 0.0  step  55793  of the epoch  4 the steps is:  295793
# 0.0  step  55794  of the epoch  4 the steps is:  295794
# 0.0  step  55795  of the epoch  4 the steps is:  295795
# 0.0  step  55796  of the epoch  4 the steps is:  295796
# 0.0  step  55797  of the epoch  4 the steps is:  295797
# 0.016629883916102983  step  55798  of the epoch  4 the steps is:  295798
# 0.0  step  55799  of the epoch  4 the steps is:  295799
# 0.0  step  55800  of the epoch  4 the steps is:  295800
# 0.0  step  55801  of the epoch  4 the steps is:  295801
# 2.105021852793196  step  55802  of the epoch  4 the steps is:  295802
# 0.0  step  55803  of the epoch  4 the steps is:  295803
# 0.0  step  55804  of the epoch  4 the steps is:  295804
# 0.0  step  55805  of the epoch  4 the steps is:  295805
# 0.0  step  55806  of the epoch  4 the steps is:  295806
# 0.0  step  55807  of the epoch  4 the steps is:  295807
# 0.0  step  55808  of the epoch  4 the steps is:  295808
# 0.20465782810481503  step  55809  of the epoch  4 the steps is:  295809
# 0.0  step  55810  of the epoch  4 the steps is:  295810
# 0.0  step  55811  of the epoch  4 the steps is:  295811
# ...
# 0.0  step  59728  of the epoch  4 the steps is:  299728
# 0.0  step  59729  of the epoch  4 the steps is:  299729
# 0.0  step  59730  of the epoch  4 the steps is:  299730
# 0.0  step  59731  of the epoch  4 the steps is:  299731
# 0.0  step  59732  of the epoch  4 the steps is:  299732
# 0.0  step  59733  of the epoch  4 the steps is:  299733
# 0.0  step  59734  of the epoch  4 the steps is:  299734
# 0.0  step  59735  of the epoch  4 the steps is:  299735
# 0.0  step  59736  of the epoch  4 the steps is:  299736
# 0.0  step  59737  of the epoch  4 the steps is:  299737
# 0.0  step  59738  of the epoch  4 the steps is:  299738
# 0.0  step  59739  of the epoch  4 the steps is:  299739
# 0.0  step  59740  of the epoch  4 the steps is:  299740
# 0.0  step  59741  of the epoch  4 the steps is:  299741
# 0.0  step  59742  of the epoch  4 the steps is:  299742
# 0.3282531247646512  step  59743  of the epoch  4 the steps is:  299743
# 0.0  step  59744  of the epoch  4 the steps is:  299744
# 0.0  step  59745  of the epoch  4 the steps is:  299745
# 2.0716313853728723  step  59746  of the epoch  4 the steps is:  299746
# 0.0  step  59747  of the epoch  4 the steps is:  299747
# 0.0  step  59748  of the epoch  4 the steps is:  299748
# 0.0  step  59749  of the epoch  4 the steps is:  299749
# 0.19538785207271037  step  59750  of the epoch  4 the steps is:  299750
# 0.0  step  59751  of the epoch  4 the steps is:  299751
# 4.3849058772531535  step  59752  of the epoch  4 the steps is:  299752
# 1.3978280513392098  step  59753  of the epoch  4 the steps is:  299753
# 0.0  step  59754  of the epoch  4 the steps is:  299754
# 0.0  step  59755  of the epoch  4 the steps is:  299755
# 0.0  step  59756  of the epoch  4 the steps is:  299756
# 0.0  step  59757  of the epoch  4 the steps is:  299757
# 0.0  step  59758  of the epoch  4 the steps is:  299758
# 0.0  step  59759  of the epoch  4 the steps is:  299759
# 0.0  step  59760  of the epoch  4 the steps is:  299760
# 0.0  step  59761  of the epoch  4 the steps is:  299761
# 2.434235218879747  step  59762  of the epoch  4 the steps is:  299762
# 0.0  step  59763  of the epoch  4 the steps is:  299763
# 0.0  step  59764  of the epoch  4 the steps is:  299764
# 0.0  step  59765  of the epoch  4 the steps is:  299765
# 0.0  step  59766  of the epoch  4 the steps is:  299766
# 0.0  step  59767  of the epoch  4 the steps is:  299767
# 0.0  step  59768  of the epoch  4 the steps is:  299768
# 0.08833208250368685  step  59769  of the epoch  4 the steps is:  299769
# 0.0  step  59770  of the epoch  4 the steps is:  299770
# 1.05369109382226  step  59771  of the epoch  4 the steps is:  299771
# 0.1337600091641047  step  59772  of the epoch  4 the steps is:  299772
# 0.0  step  59773  of the epoch  4 the steps is:  299773
# 1.3105862620400175  step  59774  of the epoch  4 the steps is:  299774
# 0.0  step  59775  of the epoch  4 the steps is:  299775
# 0.0  step  59776  of the epoch  4 the steps is:  299776
# 0.0  step  59777  of the epoch  4 the steps is:  299777
# 0.0  step  59778  of the epoch  4 the steps is:  299778
# 0.0  step  59779  of the epoch  4 the steps is:  299779
# 0.0  step  59780  of the epoch  4 the steps is:  299780
# 0.0  step  59781  of the epoch  4 the steps is:  299781
# 0.0  step  59782  of the epoch  4 the steps is:  299782
# 0.0  step  59783  of the epoch  4 the steps is:  299783
# 0.0  step  59784  of the epoch  4 the steps is:  299784
# 0.0  step  59785  of the epoch  4 the steps is:  299785
# 1.9735690964143369  step  59786  of the epoch  4 the steps is:  299786
# 0.0  step  59787  of the epoch  4 the steps is:  299787
# 0.0  step  59788  of the epoch  4 the steps is:  299788
# 0.0  step  59789  of the epoch  4 the steps is:  299789
# 0.0  step  59790  of the epoch  4 the steps is:  299790
# 0.6977236044356312  step  59791  of the epoch  4 the steps is:  299791
# 0.0  step  59792  of the epoch  4 the steps is:  299792
# 0.0  step  59793  of the epoch  4 the steps is:  299793
# 1.364835452176866  step  59794  of the epoch  4 the steps is:  299794
# 0.0  step  59795  of the epoch  4 the steps is:  299795
# 0.0  step  59796  of the epoch  4 the steps is:  299796
# 0.0  step  59797  of the epoch  4 the steps is:  299797
# 0.0  step  59798  of the epoch  4 the steps is:  299798
# 0.0  step  59799  of the epoch  4 the steps is:  299799
# 0.0  step  59800  of the epoch  4 the steps is:  299800
# 0.030901912041254143  step  59801  of the epoch  4 the steps is:  299801
# 0.0  step  59802  of the epoch  4 the steps is:  299802
# 0.0  step  59803  of the epoch  4 the steps is:  299803
# 1.1048632021449931  step  59804  of the epoch  4 the steps is:  299804
# 0.0  step  59805  of the epoch  4 the steps is:  299805
# 0.0  step  59806  of the epoch  4 the steps is:  299806
# 0.0  step  59807  of the epoch  4 the steps is:  299807
# 0.0  step  59808  of the epoch  4 the steps is:  299808
# 0.0  step  59809  of the epoch  4 the steps is:  299809
# 0.0  step  59810  of the epoch  4 the steps is:  299810
# 0.0  step  59811  of the epoch  4 the steps is:  299811
# 0.0  step  59812  of the epoch  4 the steps is:  299812
# 0.9659008645567528  step  59813  of the epoch  4 the steps is:  299813
# 0.0  step  59814  of the epoch  4 the steps is:  299814
# 0.0  step  59815  of the epoch  4 the steps is:  299815
# 0.0  step  59816  of the epoch  4 the steps is:  299816
# 0.0  step  59817  of the epoch  4 the steps is:  299817
# 0.0  step  59818  of the epoch  4 the steps is:  299818
# 0.0  step  59819  of the epoch  4 the steps is:  299819
# 0.0  step  59820  of the epoch  4 the steps is:  299820
# 0.0  step  59821  of the epoch  4 the steps is:  299821
# 0.0  step  59822  of the epoch  4 the steps is:  299822
# 0.0  step  59823  of the epoch  4 the steps is:  299823
# 0.0  step  59824  of the epoch  4 the steps is:  299824
# 0.0  step  59825  of the epoch  4 the steps is:  299825
# 0.0  step  59826  of the epoch  4 the steps is:  299826
# 0.0  step  59827  of the epoch  4 the steps is:  299827
# 0.0  step  59828  of the epoch  4 the steps is:  299828
# 0.0  step  59829  of the epoch  4 the steps is:  299829
# 0.0  step  59830  of the epoch  4 the steps is:  299830
# 0.0  step  59831  of the epoch  4 the steps is:  299831
# 0.0  step  59832  of the epoch  4 the steps is:  299832
# 0.0  step  59833  of the epoch  4 the steps is:  299833
# 0.0  step  59834  of the epoch  4 the steps is:  299834
# 0.0  step  59835  of the epoch  4 the steps is:  299835
# 0.0  step  59836  of the epoch  4 the steps is:  299836
# 0.6196252270253346  step  59837  of the epoch  4 the steps is:  299837
# 0.0  step  59838  of the epoch  4 the steps is:  299838
# 0.13823164329363813  step  59839  of the epoch  4 the steps is:  299839
# 0.0  step  59840  of the epoch  4 the steps is:  299840
# 0.0  step  59841  of the epoch  4 the steps is:  299841
# 0.03598116676353813  step  59842  of the epoch  4 the steps is:  299842
# 0.0  step  59843  of the epoch  4 the steps is:  299843
# 0.0  step  59844  of the epoch  4 the steps is:  299844
# 0.0  step  59845  of the epoch  4 the steps is:  299845
# 0.0  step  59846  of the epoch  4 the steps is:  299846
# 0.0  step  59847  of the epoch  4 the steps is:  299847
# 0.0  step  59848  of the epoch  4 the steps is:  299848
# 0.0  step  59849  of the epoch  4 the steps is:  299849
# 0.0  step  59850  of the epoch  4 the steps is:  299850
# 0.0  step  59851  of the epoch  4 the steps is:  299851
# 0.6193779752319486  step  59852  of the epoch  4 the steps is:  299852
# 0.0  step  59853  of the epoch  4 the steps is:  299853
# 0.0  step  59854  of the epoch  4 the steps is:  299854
# 0.0  step  59855  of the epoch  4 the steps is:  299855
# 0.0  step  59856  of the epoch  4 the steps is:  299856
# 0.0  step  59857  of the epoch  4 the steps is:  299857
# 0.0  step  59858  of the epoch  4 the steps is:  299858
# 0.3160727437065516  step  59859  of the epoch  4 the steps is:  299859
# 0.0  step  59860  of the epoch  4 the steps is:  299860
# 0.0  step  59861  of the epoch  4 the steps is:  299861
# 0.0  step  59862  of the epoch  4 the steps is:  299862
# 0.014281537274546174  step  59863  of the epoch  4 the steps is:  299863
# 0.0  step  59864  of the epoch  4 the steps is:  299864
# 0.6774966354516216  step  59865  of the epoch  4 the steps is:  299865
# 0.0  step  59866  of the epoch  4 the steps is:  299866
# 0.0  step  59867  of the epoch  4 the steps is:  299867
# 0.0  step  59868  of the epoch  4 the steps is:  299868
# 0.0  step  59869  of the epoch  4 the steps is:  299869
# 2.280348803044029  step  59870  of the epoch  4 the steps is:  299870
# 0.0  step  59871  of the epoch  4 the steps is:  299871
# 0.0  step  59872  of the epoch  4 the steps is:  299872
# 0.0  step  59873  of the epoch  4 the steps is:  299873
# 0.0  step  59874  of the epoch  4 the steps is:  299874
# 0.0  step  59875  of the epoch  4 the steps is:  299875
# 0.0  step  59876  of the epoch  4 the steps is:  299876
# 0.0  step  59877  of the epoch  4 the steps is:  299877
# 0.0  step  59878  of the epoch  4 the steps is:  299878
# 0.0  step  59879  of the epoch  4 the steps is:  299879
# 0.7682606938509569  step  59880  of the epoch  4 the steps is:  299880
# 0.0920560199838798  step  59881  of the epoch  4 the steps is:  299881
# 0.0  step  59882  of the epoch  4 the steps is:  299882
# 2.023733599077546  step  59883  of the epoch  4 the steps is:  299883
# 0.0  step  59884  of the epoch  4 the steps is:  299884
# 0.0  step  59885  of the epoch  4 the steps is:  299885
# 0.18674633595467593  step  59886  of the epoch  4 the steps is:  299886
# 0.0  step  59887  of the epoch  4 the steps is:  299887
# 0.0  step  59888  of the epoch  4 the steps is:  299888
# 0.0  step  59889  of the epoch  4 the steps is:  299889
# 0.0  step  59890  of the epoch  4 the steps is:  299890
# 0.0  step  59891  of the epoch  4 the steps is:  299891
# 0.0  step  59892  of the epoch  4 the steps is:  299892
# 0.0  step  59893  of the epoch  4 the steps is:  299893
# 0.0  step  59894  of the epoch  4 the steps is:  299894
# 2.213885689981306  step  59895  of the epoch  4 the steps is:  299895
# 0.6504364835296688  step  59896  of the epoch  4 the steps is:  299896
# 0.0  step  59897  of the epoch  4 the steps is:  299897
# 0.0  step  59898  of the epoch  4 the steps is:  299898
# 0.0  step  59899  of the epoch  4 the steps is:  299899
# 0.0  step  59900  of the epoch  4 the steps is:  299900
# 0.0  step  59901  of the epoch  4 the steps is:  299901
# 0.0  step  59902  of the epoch  4 the steps is:  299902
# 0.0  step  59903  of the epoch  4 the steps is:  299903
# 2.4427156434638753  step  59904  of the epoch  4 the steps is:  299904
# 0.0  step  59905  of the epoch  4 the steps is:  299905
# 0.6562967367088319  step  59906  of the epoch  4 the steps is:  299906
# 0.0  step  59907  of the epoch  4 the steps is:  299907
# 0.0  step  59908  of the epoch  4 the steps is:  299908
# 0.0  step  59909  of the epoch  4 the steps is:  299909
# 0.0  step  59910  of the epoch  4 the steps is:  299910
# 2.928446509195767  step  59911  of the epoch  4 the steps is:  299911
# 0.0  step  59912  of the epoch  4 the steps is:  299912
# 0.0  step  59913  of the epoch  4 the steps is:  299913
# 0.0  step  59914  of the epoch  4 the steps is:  299914
# 0.0  step  59915  of the epoch  4 the steps is:  299915
# 0.0  step  59916  of the epoch  4 the steps is:  299916
# 0.0  step  59917  of the epoch  4 the steps is:  299917
# 0.0  step  59918  of the epoch  4 the steps is:  299918
# 0.0  step  59919  of the epoch  4 the steps is:  299919
# 0.0  step  59920  of the epoch  4 the steps is:  299920
# 0.0  step  59921  of the epoch  4 the steps is:  299921
# 0.0  step  59922  of the epoch  4 the steps is:  299922
# 0.0  step  59923  of the epoch  4 the steps is:  299923
# 0.0  step  59924  of the epoch  4 the steps is:  299924
# 0.0  step  59925  of the epoch  4 the steps is:  299925
# 1.6117856001118658  step  59926  of the epoch  4 the steps is:  299926
# 0.0  step  59927  of the epoch  4 the steps is:  299927
# 0.0  step  59928  of the epoch  4 the steps is:  299928
# 0.0  step  59929  of the epoch  4 the steps is:  299929
# 0.0  step  59930  of the epoch  4 the steps is:  299930
# 0.0  step  59931  of the epoch  4 the steps is:  299931
# 0.0  step  59932  of the epoch  4 the steps is:  299932
# 0.0  step  59933  of the epoch  4 the steps is:  299933
# 0.0  step  59934  of the epoch  4 the steps is:  299934
# 0.0  step  59935  of the epoch  4 the steps is:  299935
# 0.0  step  59936  of the epoch  4 the steps is:  299936
# 0.0  step  59937  of the epoch  4 the steps is:  299937
# 0.0  step  59938  of the epoch  4 the steps is:  299938
# 0.9231795893495169  step  59939  of the epoch  4 the steps is:  299939
# 0.0  step  59940  of the epoch  4 the steps is:  299940
# 0.0  step  59941  of the epoch  4 the steps is:  299941
# 0.0879919012022885  step  59942  of the epoch  4 the steps is:  299942
# 0.0  step  59943  of the epoch  4 the steps is:  299943
# 0.0  step  59944  of the epoch  4 the steps is:  299944
# 0.0  step  59945  of the epoch  4 the steps is:  299945
# 0.0  step  59946  of the epoch  4 the steps is:  299946
# 1.850842269389093  step  59947  of the epoch  4 the steps is:  299947
# 0.0  step  59948  of the epoch  4 the steps is:  299948
# 1.6661803891961222  step  59949  of the epoch  4 the steps is:  299949
# 0.0  step  59950  of the epoch  4 the steps is:  299950
# 0.0  step  59951  of the epoch  4 the steps is:  299951
# 0.0  step  59952  of the epoch  4 the steps is:  299952
# 0.0  step  59953  of the epoch  4 the steps is:  299953
# 0.0  step  59954  of the epoch  4 the steps is:  299954
# 2.5966763423787764  step  59955  of the epoch  4 the steps is:  299955
# 0.0  step  59956  of the epoch  4 the steps is:  299956
# 0.0  step  59957  of the epoch  4 the steps is:  299957
# 0.0  step  59958  of the epoch  4 the steps is:  299958
# 0.0  step  59959  of the epoch  4 the steps is:  299959
# 0.0  step  59960  of the epoch  4 the steps is:  299960
# 0.0  step  59961  of the epoch  4 the steps is:  299961
# 0.0  step  59962  of the epoch  4 the steps is:  299962
# 0.0  step  59963  of the epoch  4 the steps is:  299963
# 0.0  step  59964  of the epoch  4 the steps is:  299964
# 0.04808496761201475  step  59965  of the epoch  4 the steps is:  299965
# 0.0  step  59966  of the epoch  4 the steps is:  299966
# 0.0  step  59967  of the epoch  4 the steps is:  299967
# 2.2627256021746875  step  59968  of the epoch  4 the steps is:  299968
# 0.0  step  59969  of the epoch  4 the steps is:  299969
# 0.0  step  59970  of the epoch  4 the steps is:  299970
# 0.0  step  59971  of the epoch  4 the steps is:  299971
# 0.0  step  59972  of the epoch  4 the steps is:  299972
# 0.6591196501579084  step  59973  of the epoch  4 the steps is:  299973
# 0.0  step  59974  of the epoch  4 the steps is:  299974
# 0.0  step  59975  of the epoch  4 the steps is:  299975
# 0.0  step  59976  of the epoch  4 the steps is:  299976
# 0.0  step  59977  of the epoch  4 the steps is:  299977
# 0.0  step  59978  of the epoch  4 the steps is:  299978
# 0.0  step  59979  of the epoch  4 the steps is:  299979
# 0.0  step  59980  of the epoch  4 the steps is:  299980
# 0.7012372511195659  step  59981  of the epoch  4 the steps is:  299981
# 0.0  step  59982  of the epoch  4 the steps is:  299982
# 0.0  step  59983  of the epoch  4 the steps is:  299983
# 0.3251154772835725  step  59984  of the epoch  4 the steps is:  299984
# 0.0  step  59985  of the epoch  4 the steps is:  299985
# 0.0  step  59986  of the epoch  4 the steps is:  299986
# 0.09958286203827615  step  59987  of the epoch  4 the steps is:  299987
# 0.0  step  59988  of the epoch  4 the steps is:  299988
# 0.0  step  59989  of the epoch  4 the steps is:  299989
# 0.3459962340756668  step  59990  of the epoch  4 the steps is:  299990
# 0.0  step  59991  of the epoch  4 the steps is:  299991
# 0.0  step  59992  of the epoch  4 the steps is:  299992
# 0.13362496087996956  step  59993  of the epoch  4 the steps is:  299993
# 0.0  step  59994  of the epoch  4 the steps is:  299994
# 0.0  step  59995  of the epoch  4 the steps is:  299995
# 0.0  step  59996  of the epoch  4 the steps is:  299996
# 0.0  step  59997  of the epoch  4 the steps is:  299997
# 0.0  step  59998  of the epoch  4 the steps is:  299998
# 0.0  step  59999  of the epoch  4 the steps is:  299999
# 0.9146666666666666
# time of train : 1021.9091816320001

# %%
MyNetwork.Test_Network(Test_data, Test_label)
MyNetwork.Test_Network(Train_data, Train_label)
# Out:
# 0.8793
# 0.9146666666666666
# 0.9146666666666666

# %%
plt.plot(np.arange(1,len(MyNetwork.accuracy_graph_epoch)+1), MyNetwork.accuracy_graph_epoch)
plt.ylabel('Accuracy')
plt.xlabel("number epoch")
plt.grid(True)
plt.show()
print( MyNetwork.accuracy_graph_epoch)
# Out:
# [0.8704166666666666, 0.88975, 0.90055, 0.9093833333333333, 0.9146666666666666]

# %%
plt.plot(np.arange(1,len(MyNetwork.loss_graph)+1), MyNetwork.loss_graph)
plt.ylabel('loss')
plt.xlabel("number steps")
plt.grid(True)
plt.show()

# %% [markdown]
# We can also save the weights of our network

# %%
for i in range(MyNetwork.number_hidden_layer + 1):
  pd.DataFrame(MyNetwork.weight["w" + str(i)]).to_csv("/content/drive/My Drive/Deep Learning Course Spring 99/DataSets/Fashion-MNIST/w" + str(i) + ".csv", index=False, header=False)
  pd.DataFrame(MyNetwork.weight["b" + str(i)]).to_csv("/content/drive/My Drive/Deep Learning Course Spring 99/DataSets/Fashion-MNIST/b" + str(i) + ".csv", index=False, header=False)
  pd.DataFrame(MyNetwork.accuracy_graph).to_csv("/content/drive/My Drive/Deep Learning Course Spring 99/DataSets/Fashion-MNIST/accuracy.csv", index=False, header=False)
  pd.DataFrame(MyNetwork.loss_graph).to_csv("/content/drive/My Drive/Deep Learning Course Spring 99/DataSets/Fashion-MNIST/loss.csv", index=False, header=False)
